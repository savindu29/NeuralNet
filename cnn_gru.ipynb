# %% [markdown]
# <a href="https://colab.research.google.com/github/savindu29/NeuralNet/blob/main/cnn_gru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install torch-summary

# %%
import math
import copy
import gdown
import random
import scipy.io
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt


# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import os

# Mount Google Drive (only for Colab users)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_save_path = "/content/drive/MyDrive/Preprocessed_Data"
# Define separate paths for NumPy and PyTorch tensors
numpy_save_path = os.path.join(root_save_path, "numpy_data")
torch_save_path = os.path.join(root_save_path, "torch_data")

# %%
# Load NumPy arrays
X_train = np.load(os.path.join(numpy_save_path, "X_train.npy"))
X_test = np.load(os.path.join(numpy_save_path, "X_test.npy"))
y_train = np.load(os.path.join(numpy_save_path, "y_train.npy"))
y_test = np.load(os.path.join(numpy_save_path, "y_test.npy"))

# Print loaded shapes
print("Loaded NumPy Data:")
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# Choosing Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1).to(device)  # Add missing dimension
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.long).to(device)

# Create Tensor Dataset
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# Print dataset sizes
print("\nProcessed PyTorch Tensors:")
print("X_train shape:", X_train_tensor.size())
print("X_test shape:", X_test_tensor.size())
print("y_train shape:", y_train_tensor.size())
print("y_test shape:", y_test_tensor.size())

print("✅ Data successfully loaded and processed!")
# Out:
# Loaded NumPy Data:
# X_train shape: (4147, 22, 1001)
# X_test shape: (1037, 22, 1001)
# y_train shape: (4147,)
# y_test shape: (1037,)
#
# Processed PyTorch Tensors:
# X_train shape: torch.Size([4147, 1, 22, 1001])
# X_test shape: torch.Size([1037, 1, 22, 1001])
# y_train shape: torch.Size([4147])
# y_test shape: torch.Size([1037])
# ✅ Data successfully loaded and processed!

# %% [markdown]
# # Model Training class

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import numpy as np
import matplotlib.pyplot as plt

class TrainModel():
    def __init__(self, patience=10):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.train_loss = []  # To store training loss for plotting
        self.train_accuracy = []  # To store training accuracy for plotting
        self.val_loss = []  # To store validation loss for plotting
        self.val_accuracy = []  # To store validation accuracy for plotting

    def train_model(self, model, train_dataset, validation_dataset=None, learning_rate=0.001, batch_size=64, epochs=500):
        # Send the model to the device (GPU or CPU)
        model = model.to(self.device)

        # Loss function and optimizer
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # Initialize the ReduceLROnPlateau scheduler
        scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=10, factor=0.5, verbose=True)

        # Create DataLoader for training data
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        # Track highest accuracy and patience for Early Stopping
        highest_train_accuracy = 0.0
        best_epoch = 0
        early_stopping_counter = 0

        for epoch in range(epochs):
            model.train()  # Set the model to training mode
            running_loss = 0.0
            correct = 0
            total = 0

            # Training loop
            for inputs, labels in train_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                optimizer.zero_grad()  # Zero the gradients

                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Backward pass and optimization
                loss.backward()
                optimizer.step()

                # Track running loss and accuracy
                running_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            # Calculate epoch loss and accuracy
            epoch_loss = running_loss / len(train_loader.dataset)
            epoch_accuracy = correct / total

            # Update the learning rate scheduler based on training loss
            scheduler.step(epoch_loss)  # Reduce learning rate if loss doesn't improve

            # Collect the data for plotting
            self.train_loss.append(epoch_loss)
            self.train_accuracy.append(epoch_accuracy)

            # Validation step
            if validation_dataset is not None:
                val_loss, val_accuracy = self.validate_model(model, validation_dataset, criterion)
                self.val_loss.append(val_loss)
                self.val_accuracy.append(val_accuracy)

                print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {(epoch_accuracy*100):.2f}%, "
                      f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy*100:.2f}%")
            else:
                print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {(epoch_accuracy*100):.2f}%")

            # Early stopping
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy
                best_epoch = epoch
            #     early_stopping_counter = 0  # Reset the early stopping counter
            # else:
            #     early_stopping_counter += 1  # Increment the counter if no improvement

            # # Check for early stopping
            # if early_stopping_counter >= self.patience:
            #     print("Early stopping triggered")
            #     break

        # Calculate the average training loss over all epochs
        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)
        print("Highest Train Accuracy:", highest_train_accuracy)

        # Saving the trained model
        torch.save(model.state_dict(), 'trained_model.pth')

        # Plotting the results
        self.plot_results()

        return model

    def validate_model(self, model, validation_dataset, criterion):
        """Validation step to monitor the validation performance."""
        model.eval()  # Set the model to evaluation mode
        val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)

        val_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():  # No need to track gradients during validation
            for inputs, labels in val_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        # Calculate validation loss and accuracy
        val_loss = val_loss / len(validation_dataset)
        val_accuracy = correct_val / total_val
        return val_loss, val_accuracy

    def plot_results(self):
        """Plot training and validation loss and accuracy."""
        epochs = len(self.train_loss)

        plt.figure(figsize=(10, 6))

        # Plot accuracy
        plt.subplot(1, 2, 1)
        plt.plot(range(epochs), self.train_accuracy, label='accuracy', color='blue')
        plt.plot(range(epochs), self.val_accuracy, label='val_accuracy', color='blue', linestyle='dotted')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy vs Epochs')
        plt.legend()

        # Plot loss
        plt.subplot(1, 2, 2)
        plt.plot(range(epochs), self.train_loss, label='loss', color='red')
        plt.plot(range(epochs), self.val_loss, label='val_loss', color='red', linestyle='dotted')
        plt.xlabel('Epochs')
        plt.ylabel('Loss (cross-entropy)')
        plt.title('Loss vs Epochs')
        plt.legend()

        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Model Evaluation class

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, cohen_kappa_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class EvalModel():
    def __init__(self, model):
        self.model = model.to(device)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def test_model(self, test_dataset):
        self.model.eval()
        correct = 0
        total = 0
        test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
        y_true = []
        y_pred = []

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

        accuracy = (correct / total) * 100
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")

        return accuracy, y_true, y_pred

    def print_classification_report(self, y_true, y_pred, target_names):
        print("Classification Report:\n")
        report = classification_report(y_true, y_pred, target_names=target_names)
        print(report)

    def plot_confusion_matrix(self, y_true, y_pred, classes):
        cf_matrix = confusion_matrix(y_true, y_pred)
        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        plt.figure(figsize=(10, 7))
        sns.heatmap(df_cm, annot=True, cmap='Blues', fmt='d')  # 'd' ensures actual counts, not percentages
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.savefig('confusion_matrix_model.png')
        plt.show()


    def plot_metrics(self, hist):
        # Plot accuracy and loss
        fig, ax = plt.subplots()
        ax.plot(hist['accuracy'], color='b', label='accuracy')
        ax.plot(hist['val_accuracy'], linestyle=':', color='b', label='val_accuracy')
        ax.set_ylabel("Accuracy", color='b')
        ax.set_ylim([0, 1])

        ax2 = ax.twinx()
        ax2.plot(hist['loss'], color='r', label='loss')
        ax2.plot(hist['val_loss'], linestyle=':', color='r', label='val_loss')
        ax2.set_ylabel("Loss (cross-entropy)", color='r')

        fig.legend(loc='best')
        plt.title('Accuracy and Loss over Epochs')
        plt.show()

    def plot_classification_metrics(self, y_true, y_pred, target_names):
        # Classification report and metrics
        report = classification_report(y_true, y_pred, target_names=target_names, output_dict=True)
        report_df = pd.DataFrame(report).transpose()

        # Plot metrics
        report_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(10, 7))
        plt.title('Classification Report Metrics')
        plt.xlabel('Classes')
        plt.ylabel('Scores')
        plt.legend(loc='lower right')
        plt.show()

        # Plot Cohen's Kappa score
        kappa = cohen_kappa_score(y_true, y_pred)
        print(f"Cohen's Kappa: {kappa:.4f}")

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn

class CNN_GRU(nn.Module):  # EEGNet with 2D CNN + GRU
    def __init__(self, chans=22, classes=4, time_points=1001, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, gru_hidden_size=128,
                 gru_layers=2, dropout_rate=0.5, max_norm1=1, max_norm2=0.25):
        super(CNN_GRU, self).__init__()
        # Calculating the number of features after CNN layers for GRU input
        linear_size = (time_points // (pk1 * pk2)) * f2

        # Temporal Filters
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )

        # Spatial Filters
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False),  # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )

        # Separable and Pointwise Convolutions
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16), groups=f2, bias=False, padding='same'),  # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False),  # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )

        # Flatten and reshape to feed into GRU
        self.flatten = nn.Flatten()

        # GRU for temporal context learning
        self.gru = nn.GRU(input_size=linear_size, hidden_size=gru_hidden_size, num_layers=gru_layers,
                          batch_first=True, dropout=dropout_rate, bidirectional=True)

        # Fully connected layer
        self.fc = nn.Linear(2 * gru_hidden_size, classes)  # Bidirectional GRU doubles hidden size

        # Apply max_norm constraint to the depthwise layer in block2
        self._apply_max_norm(self.block2[0], max_norm1)

        # Apply max_norm constraint to the linear layer
        self._apply_max_norm(self.fc, max_norm2)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.flatten(x)

        # Reshape for GRU input: (batch_size, sequence_length, features)
        batch_size = x.size(0)
        x = x.view(batch_size, -1, x.size(1))

        # Pass through GRU
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]  # Take the output of the last time step

        # Final classification
        x = self.fc(gru_out)
        return x

# %% [markdown]
# # Summary

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Model Parameters
chans = 22
classes = 4
time_points = 1001
f1 = 32  # Number of filters for the first convolutional layer
f2 = 64  # Number of filters for the second convolutional layer
lstm_hidden_size = 64  # Reduce hidden size to prevent overfitting
dropout_rate = 0.5  # Increase dropout for regularization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Correcting the class instantiation
improved_model = CNN_GRU(
    chans=chans, classes=classes, time_points=time_points,
    f1=f1, f2=f2, dropout_rate=dropout_rate
).to(device)

# Display the summary of the model
summary(improved_model, input_size=(1, chans, time_points))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,024
# |    └─BatchNorm2d: 2-2                  64
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       1,408
# |    └─BatchNorm2d: 2-4                  128
# |    └─ELU: 2-5                          --
# |    └─AvgPool2d: 2-6                    --
# |    └─Dropout: 2-7                      --
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-8                       1,024
# |    └─Conv2d: 2-9                       4,096
# |    └─BatchNorm2d: 2-10                 128
# |    └─ELU: 2-11                         --
# |    └─AvgPool2d: 2-12                   --
# |    └─Dropout: 2-13                     --
# ├─Flatten: 1-4                           --
# ├─GRU: 1-5                               740,352
# ├─Linear: 1-6                            1,028
# =================================================================
# Total params: 749,252
# Trainable params: 749,252
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,024
# |    └─BatchNorm2d: 2-2                  64
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       1,408
# |    └─BatchNorm2d: 2-4                  128
# |    └─ELU: 2-5                          --
# |    └─AvgPool2d: 2-6                    --
# |    └─Dropout: 2-7                      --
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-8                       1,024
# |    └─Conv2d: 2-9                       4,096
# |    └─BatchNorm2d: 2-10                 128
# |    └─ELU: 2-11                         --
# |    └─AvgPool2d: 2-12                   --
# |    └─Dropout: 2-13                     --
# ├─Flatten: 1-4                           --
# ├─GRU: 1-5                               740,352
# ├─Linear: 1-6                            1,028
# =================================================================
# Total params: 749,252
# Trainable params: 749,252
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Train the model

# %%
# Training Hyperparameters
EPOCHS = 300
BATCH_SIZE = 64
LEARNING_RATE = 0.001
trainer = TrainModel(patience=10)
trained_cnn_gru_model = trainer.train_model(improved_model, train_dataset, validation_dataset=test_dataset,learning_rate=LEARNING_RATE,
                                   batch_size=BATCH_SIZE, epochs=EPOCHS)
torch.save(trained_cnn_gru_model.state_dict(), 'cnn_gru_model.pth')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1036.)
#   return F.conv2d(
# Epoch 1/300, Train Loss: 1.3619, Train Accuracy: 30.34%, Validation Loss: 1.3019, Validation Accuracy: 39.15%
# Epoch 2/300, Train Loss: 1.2971, Train Accuracy: 37.14%, Validation Loss: 1.2385, Validation Accuracy: 41.56%
# Epoch 3/300, Train Loss: 1.2436, Train Accuracy: 42.32%, Validation Loss: 1.1420, Validation Accuracy: 47.54%
# Epoch 4/300, Train Loss: 1.1864, Train Accuracy: 44.32%, Validation Loss: 1.0989, Validation Accuracy: 51.98%
# Epoch 5/300, Train Loss: 1.1708, Train Accuracy: 45.50%, Validation Loss: 1.1029, Validation Accuracy: 50.05%
# Epoch 6/300, Train Loss: 1.1435, Train Accuracy: 46.88%, Validation Loss: 1.0740, Validation Accuracy: 49.18%
# Epoch 7/300, Train Loss: 1.1309, Train Accuracy: 48.49%, Validation Loss: 1.0455, Validation Accuracy: 49.95%
# Epoch 8/300, Train Loss: 1.1149, Train Accuracy: 49.00%, Validation Loss: 1.0299, Validation Accuracy: 53.13%
# Epoch 9/300, Train Loss: 1.0904, Train Accuracy: 49.29%, Validation Loss: 1.0392, Validation Accuracy: 50.53%
# Epoch 10/300, Train Loss: 1.0795, Train Accuracy: 50.49%, Validation Loss: 1.0249, Validation Accuracy: 52.94%
# Epoch 11/300, Train Loss: 1.0655, Train Accuracy: 52.06%, Validation Loss: 1.0355, Validation Accuracy: 51.59%
# Epoch 12/300, Train Loss: 1.0642, Train Accuracy: 51.29%, Validation Loss: 0.9913, Validation Accuracy: 54.10%
# Epoch 13/300, Train Loss: 1.0674, Train Accuracy: 51.58%, Validation Loss: 0.9849, Validation Accuracy: 55.26%
# Epoch 14/300, Train Loss: 1.0253, Train Accuracy: 54.09%, Validation Loss: 0.9987, Validation Accuracy: 54.29%
# Epoch 15/300, Train Loss: 1.0124, Train Accuracy: 54.57%, Validation Loss: 0.9502, Validation Accuracy: 56.99%
# Epoch 16/300, Train Loss: 1.0122, Train Accuracy: 54.71%, Validation Loss: 0.9571, Validation Accuracy: 57.86%
# Epoch 17/300, Train Loss: 1.0106, Train Accuracy: 54.45%, Validation Loss: 0.9464, Validation Accuracy: 56.51%
# Epoch 18/300, Train Loss: 0.9743, Train Accuracy: 56.35%, Validation Loss: 0.9243, Validation Accuracy: 58.15%
# Epoch 19/300, Train Loss: 0.9566, Train Accuracy: 56.79%, Validation Loss: 0.9345, Validation Accuracy: 57.28%
# Epoch 20/300, Train Loss: 0.9535, Train Accuracy: 57.39%, Validation Loss: 0.9162, Validation Accuracy: 58.53%
# Epoch 21/300, Train Loss: 0.9468, Train Accuracy: 58.21%, Validation Loss: 0.9076, Validation Accuracy: 58.63%
# Epoch 22/300, Train Loss: 0.9358, Train Accuracy: 58.96%, Validation Loss: 0.9092, Validation Accuracy: 58.73%
# Epoch 23/300, Train Loss: 0.9189, Train Accuracy: 60.02%, Validation Loss: 0.8997, Validation Accuracy: 59.40%
# Epoch 24/300, Train Loss: 0.9087, Train Accuracy: 60.60%, Validation Loss: 0.8676, Validation Accuracy: 62.39%
# Epoch 25/300, Train Loss: 0.9100, Train Accuracy: 59.46%, Validation Loss: 0.8773, Validation Accuracy: 61.23%
# Epoch 26/300, Train Loss: 0.9045, Train Accuracy: 60.33%, Validation Loss: 0.8908, Validation Accuracy: 59.31%
# Epoch 27/300, Train Loss: 0.8783, Train Accuracy: 61.73%, Validation Loss: 0.8643, Validation Accuracy: 62.10%
# Epoch 28/300, Train Loss: 0.8890, Train Accuracy: 60.62%, Validation Loss: 0.9107, Validation Accuracy: 59.98%
# Epoch 29/300, Train Loss: 0.8743, Train Accuracy: 62.00%, Validation Loss: 0.8629, Validation Accuracy: 61.52%
# Epoch 30/300, Train Loss: 0.8706, Train Accuracy: 62.38%, Validation Loss: 0.8718, Validation Accuracy: 60.75%
# Epoch 31/300, Train Loss: 0.8471, Train Accuracy: 62.96%, Validation Loss: 0.8658, Validation Accuracy: 63.07%
# Epoch 32/300, Train Loss: 0.8532, Train Accuracy: 63.27%, Validation Loss: 0.8369, Validation Accuracy: 63.93%
# Epoch 33/300, Train Loss: 0.8335, Train Accuracy: 63.37%, Validation Loss: 0.8595, Validation Accuracy: 62.58%
# Epoch 34/300, Train Loss: 0.8572, Train Accuracy: 63.25%, Validation Loss: 0.7997, Validation Accuracy: 66.25%
# Epoch 35/300, Train Loss: 0.8339, Train Accuracy: 64.00%, Validation Loss: 0.8423, Validation Accuracy: 62.58%
# Epoch 36/300, Train Loss: 0.8074, Train Accuracy: 65.23%, Validation Loss: 0.8199, Validation Accuracy: 64.03%
# Epoch 37/300, Train Loss: 0.8182, Train Accuracy: 65.47%, Validation Loss: 0.8405, Validation Accuracy: 63.65%
# Epoch 38/300, Train Loss: 0.7915, Train Accuracy: 66.72%, Validation Loss: 0.8455, Validation Accuracy: 64.22%
# Epoch 39/300, Train Loss: 0.8099, Train Accuracy: 64.31%, Validation Loss: 0.8149, Validation Accuracy: 65.19%
# Epoch 40/300, Train Loss: 0.8106, Train Accuracy: 64.94%, Validation Loss: 0.8215, Validation Accuracy: 64.32%
# Epoch 41/300, Train Loss: 0.7857, Train Accuracy: 67.25%, Validation Loss: 0.8138, Validation Accuracy: 65.48%
# Epoch 42/300, Train Loss: 0.7679, Train Accuracy: 67.11%, Validation Loss: 0.8150, Validation Accuracy: 65.57%
# Epoch 43/300, Train Loss: 0.7894, Train Accuracy: 66.67%, Validation Loss: 0.8098, Validation Accuracy: 64.22%
# Epoch 44/300, Train Loss: 0.7791, Train Accuracy: 66.41%, Validation Loss: 0.8175, Validation Accuracy: 63.74%
# Epoch 45/300, Train Loss: 0.7480, Train Accuracy: 68.36%, Validation Loss: 0.7888, Validation Accuracy: 67.21%
# Epoch 46/300, Train Loss: 0.7505, Train Accuracy: 66.96%, Validation Loss: 0.7842, Validation Accuracy: 65.77%
# Epoch 47/300, Train Loss: 0.7421, Train Accuracy: 68.60%, Validation Loss: 0.8142, Validation Accuracy: 65.09%
# Epoch 48/300, Train Loss: 0.7470, Train Accuracy: 68.58%, Validation Loss: 0.7803, Validation Accuracy: 65.86%
# Epoch 49/300, Train Loss: 0.7293, Train Accuracy: 68.68%, Validation Loss: 0.8030, Validation Accuracy: 65.96%
# Epoch 50/300, Train Loss: 0.7406, Train Accuracy: 68.65%, Validation Loss: 0.7924, Validation Accuracy: 65.86%
# Epoch 51/300, Train Loss: 0.7289, Train Accuracy: 69.42%, Validation Loss: 0.8312, Validation Accuracy: 64.51%
# Epoch 52/300, Train Loss: 0.7347, Train Accuracy: 69.01%, Validation Loss: 0.7680, Validation Accuracy: 67.12%
# Epoch 53/300, Train Loss: 0.6968, Train Accuracy: 70.65%, Validation Loss: 0.8045, Validation Accuracy: 66.35%
# Epoch 54/300, Train Loss: 0.7128, Train Accuracy: 69.69%, Validation Loss: 0.7948, Validation Accuracy: 66.35%
# Epoch 55/300, Train Loss: 0.7118, Train Accuracy: 71.16%, Validation Loss: 0.7684, Validation Accuracy: 67.89%
# Epoch 56/300, Train Loss: 0.7032, Train Accuracy: 70.41%, Validation Loss: 0.7965, Validation Accuracy: 65.57%
# Epoch 57/300, Train Loss: 0.6873, Train Accuracy: 70.70%, Validation Loss: 0.8004, Validation Accuracy: 66.15%
# Epoch 58/300, Train Loss: 0.6988, Train Accuracy: 69.33%, Validation Loss: 0.7779, Validation Accuracy: 67.31%
# Epoch 59/300, Train Loss: 0.6788, Train Accuracy: 71.96%, Validation Loss: 0.7855, Validation Accuracy: 67.02%
# Epoch 60/300, Train Loss: 0.6738, Train Accuracy: 71.43%, Validation Loss: 0.7962, Validation Accuracy: 66.73%
# Epoch 61/300, Train Loss: 0.6763, Train Accuracy: 71.88%, Validation Loss: 0.7677, Validation Accuracy: 67.41%
# Epoch 62/300, Train Loss: 0.6776, Train Accuracy: 70.56%, Validation Loss: 0.7718, Validation Accuracy: 67.70%
# Epoch 63/300, Train Loss: 0.6514, Train Accuracy: 73.04%, Validation Loss: 0.8114, Validation Accuracy: 65.86%
# Epoch 64/300, Train Loss: 0.6563, Train Accuracy: 71.79%, Validation Loss: 0.7513, Validation Accuracy: 68.37%
# Epoch 65/300, Train Loss: 0.6727, Train Accuracy: 71.64%, Validation Loss: 0.7743, Validation Accuracy: 67.12%
# Epoch 66/300, Train Loss: 0.6563, Train Accuracy: 72.22%, Validation Loss: 0.7885, Validation Accuracy: 66.63%
# Epoch 67/300, Train Loss: 0.6407, Train Accuracy: 73.33%, Validation Loss: 0.8219, Validation Accuracy: 64.71%
# Epoch 68/300, Train Loss: 0.6496, Train Accuracy: 73.81%, Validation Loss: 0.7634, Validation Accuracy: 69.05%
# Epoch 69/300, Train Loss: 0.6430, Train Accuracy: 73.40%, Validation Loss: 0.8228, Validation Accuracy: 65.38%
# Epoch 70/300, Train Loss: 0.6395, Train Accuracy: 73.26%, Validation Loss: 0.7818, Validation Accuracy: 66.54%
# Epoch 71/300, Train Loss: 0.6255, Train Accuracy: 73.43%, Validation Loss: 0.7906, Validation Accuracy: 67.50%
# Epoch 72/300, Train Loss: 0.6347, Train Accuracy: 73.43%, Validation Loss: 0.8182, Validation Accuracy: 65.57%
# Epoch 73/300, Train Loss: 0.6324, Train Accuracy: 73.31%, Validation Loss: 0.7825, Validation Accuracy: 66.25%
# Epoch 74/300, Train Loss: 0.6160, Train Accuracy: 74.03%, Validation Loss: 0.7769, Validation Accuracy: 68.66%
# Epoch 75/300, Train Loss: 0.6355, Train Accuracy: 73.98%, Validation Loss: 0.7738, Validation Accuracy: 68.56%
# Epoch 76/300, Train Loss: 0.6135, Train Accuracy: 73.93%, Validation Loss: 0.7837, Validation Accuracy: 68.47%
# Epoch 77/300, Train Loss: 0.6127, Train Accuracy: 74.42%, Validation Loss: 0.7915, Validation Accuracy: 67.02%
# Epoch 78/300, Train Loss: 0.6149, Train Accuracy: 74.83%, Validation Loss: 0.7643, Validation Accuracy: 68.47%
# Epoch 79/300, Train Loss: 0.6082, Train Accuracy: 74.83%, Validation Loss: 0.7797, Validation Accuracy: 67.02%
# Epoch 80/300, Train Loss: 0.5890, Train Accuracy: 75.62%, Validation Loss: 0.8093, Validation Accuracy: 67.21%
# Epoch 81/300, Train Loss: 0.5846, Train Accuracy: 75.89%, Validation Loss: 0.7998, Validation Accuracy: 67.12%
# Epoch 82/300, Train Loss: 0.5976, Train Accuracy: 74.95%, Validation Loss: 0.7683, Validation Accuracy: 68.95%
# Epoch 83/300, Train Loss: 0.5782, Train Accuracy: 75.81%, Validation Loss: 0.8122, Validation Accuracy: 67.60%
# Epoch 84/300, Train Loss: 0.5802, Train Accuracy: 76.03%, Validation Loss: 0.7717, Validation Accuracy: 68.66%
# Epoch 85/300, Train Loss: 0.5885, Train Accuracy: 74.83%, Validation Loss: 0.7615, Validation Accuracy: 68.47%
# Epoch 86/300, Train Loss: 0.5870, Train Accuracy: 75.21%, Validation Loss: 0.7582, Validation Accuracy: 68.66%
# Epoch 87/300, Train Loss: 0.5730, Train Accuracy: 76.32%, Validation Loss: 0.7890, Validation Accuracy: 68.66%
# Epoch 88/300, Train Loss: 0.5692, Train Accuracy: 76.39%, Validation Loss: 0.7820, Validation Accuracy: 68.18%
# Epoch 89/300, Train Loss: 0.5784, Train Accuracy: 75.91%, Validation Loss: 0.7787, Validation Accuracy: 68.66%
# Epoch 90/300, Train Loss: 0.5697, Train Accuracy: 76.80%, Validation Loss: 0.7811, Validation Accuracy: 66.83%
# Epoch 91/300, Train Loss: 0.5686, Train Accuracy: 76.59%, Validation Loss: 0.7755, Validation Accuracy: 69.14%
# Epoch 92/300, Train Loss: 0.5707, Train Accuracy: 76.59%, Validation Loss: 0.7745, Validation Accuracy: 69.91%
# Epoch 93/300, Train Loss: 0.5557, Train Accuracy: 77.53%, Validation Loss: 0.7892, Validation Accuracy: 67.89%
# Epoch 94/300, Train Loss: 0.5542, Train Accuracy: 76.83%, Validation Loss: 0.7617, Validation Accuracy: 67.70%
# Epoch 95/300, Train Loss: 0.5459, Train Accuracy: 77.60%, Validation Loss: 0.7394, Validation Accuracy: 69.72%
# Epoch 96/300, Train Loss: 0.5537, Train Accuracy: 77.53%, Validation Loss: 0.7621, Validation Accuracy: 70.59%
# Epoch 97/300, Train Loss: 0.5477, Train Accuracy: 77.00%, Validation Loss: 0.7642, Validation Accuracy: 69.33%
# Epoch 98/300, Train Loss: 0.5481, Train Accuracy: 77.57%, Validation Loss: 0.7746, Validation Accuracy: 68.85%
# Epoch 99/300, Train Loss: 0.5378, Train Accuracy: 77.98%, Validation Loss: 0.7836, Validation Accuracy: 68.76%
# Epoch 100/300, Train Loss: 0.5332, Train Accuracy: 78.27%, Validation Loss: 0.7699, Validation Accuracy: 70.20%
# Epoch 101/300, Train Loss: 0.5384, Train Accuracy: 77.69%, Validation Loss: 0.7664, Validation Accuracy: 67.70%
# Epoch 102/300, Train Loss: 0.5376, Train Accuracy: 77.57%, Validation Loss: 0.7586, Validation Accuracy: 69.91%
# Epoch 103/300, Train Loss: 0.5162, Train Accuracy: 78.59%, Validation Loss: 0.7493, Validation Accuracy: 69.91%
# Epoch 104/300, Train Loss: 0.5142, Train Accuracy: 79.55%, Validation Loss: 0.7552, Validation Accuracy: 70.11%
# Epoch 105/300, Train Loss: 0.5458, Train Accuracy: 77.09%, Validation Loss: 0.7527, Validation Accuracy: 68.76%
# Epoch 106/300, Train Loss: 0.5219, Train Accuracy: 77.98%, Validation Loss: 0.7373, Validation Accuracy: 68.66%
# Epoch 107/300, Train Loss: 0.5368, Train Accuracy: 78.71%, Validation Loss: 0.7536, Validation Accuracy: 69.33%
# Epoch 108/300, Train Loss: 0.5217, Train Accuracy: 79.38%, Validation Loss: 0.7775, Validation Accuracy: 69.43%
# Epoch 109/300, Train Loss: 0.5219, Train Accuracy: 79.46%, Validation Loss: 0.7742, Validation Accuracy: 68.56%
# Epoch 110/300, Train Loss: 0.5147, Train Accuracy: 78.30%, Validation Loss: 0.7942, Validation Accuracy: 68.18%
# Epoch 111/300, Train Loss: 0.5058, Train Accuracy: 79.38%, Validation Loss: 0.7753, Validation Accuracy: 70.49%
# Epoch 112/300, Train Loss: 0.5042, Train Accuracy: 79.70%, Validation Loss: 0.7789, Validation Accuracy: 70.40%
# Epoch 113/300, Train Loss: 0.5104, Train Accuracy: 79.43%, Validation Loss: 0.7709, Validation Accuracy: 69.62%
# Epoch 114/300, Train Loss: 0.4874, Train Accuracy: 80.13%, Validation Loss: 0.7764, Validation Accuracy: 69.82%
# Epoch 115/300, Train Loss: 0.5025, Train Accuracy: 79.62%, Validation Loss: 0.7732, Validation Accuracy: 69.24%
# Epoch 116/300, Train Loss: 0.4969, Train Accuracy: 79.12%, Validation Loss: 0.7768, Validation Accuracy: 68.66%
# Epoch 117/300, Train Loss: 0.4911, Train Accuracy: 79.74%, Validation Loss: 0.7676, Validation Accuracy: 69.72%
# Epoch 118/300, Train Loss: 0.4780, Train Accuracy: 81.26%, Validation Loss: 0.7484, Validation Accuracy: 71.07%
# Epoch 119/300, Train Loss: 0.4812, Train Accuracy: 79.53%, Validation Loss: 0.7636, Validation Accuracy: 70.59%
# Epoch 120/300, Train Loss: 0.4879, Train Accuracy: 80.59%, Validation Loss: 0.7661, Validation Accuracy: 70.01%
# Epoch 121/300, Train Loss: 0.4651, Train Accuracy: 81.00%, Validation Loss: 0.8127, Validation Accuracy: 69.82%
# Epoch 122/300, Train Loss: 0.4889, Train Accuracy: 80.06%, Validation Loss: 0.8092, Validation Accuracy: 68.85%
# Epoch 123/300, Train Loss: 0.4585, Train Accuracy: 81.58%, Validation Loss: 0.7495, Validation Accuracy: 71.46%
# Epoch 124/300, Train Loss: 0.4886, Train Accuracy: 79.84%, Validation Loss: 0.7886, Validation Accuracy: 69.82%
# Epoch 125/300, Train Loss: 0.4717, Train Accuracy: 80.97%, Validation Loss: 0.7299, Validation Accuracy: 71.07%
# Epoch 126/300, Train Loss: 0.4698, Train Accuracy: 81.02%, Validation Loss: 0.7583, Validation Accuracy: 70.78%
# Epoch 127/300, Train Loss: 0.4591, Train Accuracy: 80.97%, Validation Loss: 0.7729, Validation Accuracy: 70.20%
# Epoch 128/300, Train Loss: 0.4644, Train Accuracy: 81.14%, Validation Loss: 0.8040, Validation Accuracy: 69.05%
# Epoch 129/300, Train Loss: 0.4692, Train Accuracy: 80.49%, Validation Loss: 0.7563, Validation Accuracy: 70.88%
# Epoch 130/300, Train Loss: 0.4521, Train Accuracy: 82.47%, Validation Loss: 0.8062, Validation Accuracy: 70.88%
# Epoch 131/300, Train Loss: 0.4550, Train Accuracy: 81.09%, Validation Loss: 0.7707, Validation Accuracy: 70.59%
# Epoch 132/300, Train Loss: 0.4531, Train Accuracy: 81.99%, Validation Loss: 0.7658, Validation Accuracy: 71.65%
# Epoch 133/300, Train Loss: 0.4517, Train Accuracy: 81.94%, Validation Loss: 0.7475, Validation Accuracy: 70.97%
# Epoch 134/300, Train Loss: 0.4607, Train Accuracy: 81.55%, Validation Loss: 0.7439, Validation Accuracy: 71.84%
# Epoch 135/300, Train Loss: 0.4539, Train Accuracy: 81.48%, Validation Loss: 0.7797, Validation Accuracy: 71.65%
# Epoch 136/300, Train Loss: 0.4554, Train Accuracy: 81.38%, Validation Loss: 0.8074, Validation Accuracy: 70.40%
# Epoch 137/300, Train Loss: 0.4414, Train Accuracy: 82.08%, Validation Loss: 0.7597, Validation Accuracy: 70.97%
# Epoch 138/300, Train Loss: 0.4527, Train Accuracy: 82.08%, Validation Loss: 0.7983, Validation Accuracy: 70.30%
# Epoch 139/300, Train Loss: 0.4501, Train Accuracy: 81.50%, Validation Loss: 0.7498, Validation Accuracy: 70.97%
# Epoch 140/300, Train Loss: 0.4297, Train Accuracy: 82.93%, Validation Loss: 0.7446, Validation Accuracy: 71.75%
# Epoch 141/300, Train Loss: 0.4378, Train Accuracy: 83.17%, Validation Loss: 0.7605, Validation Accuracy: 70.97%
# Epoch 142/300, Train Loss: 0.4334, Train Accuracy: 82.64%, Validation Loss: 0.7540, Validation Accuracy: 71.17%
# Epoch 143/300, Train Loss: 0.4301, Train Accuracy: 82.78%, Validation Loss: 0.7587, Validation Accuracy: 72.81%
# Epoch 144/300, Train Loss: 0.4408, Train Accuracy: 82.71%, Validation Loss: 0.7802, Validation Accuracy: 72.03%
# Epoch 145/300, Train Loss: 0.4200, Train Accuracy: 83.24%, Validation Loss: 0.7445, Validation Accuracy: 73.29%
# Epoch 146/300, Train Loss: 0.4354, Train Accuracy: 83.12%, Validation Loss: 0.7518, Validation Accuracy: 70.97%
# Epoch 147/300, Train Loss: 0.4368, Train Accuracy: 82.81%, Validation Loss: 0.8063, Validation Accuracy: 70.78%
# Epoch 148/300, Train Loss: 0.4404, Train Accuracy: 81.94%, Validation Loss: 0.7469, Validation Accuracy: 72.13%
# Epoch 149/300, Train Loss: 0.4149, Train Accuracy: 83.84%, Validation Loss: 0.7713, Validation Accuracy: 71.75%
# Epoch 150/300, Train Loss: 0.4126, Train Accuracy: 83.31%, Validation Loss: 0.7856, Validation Accuracy: 71.17%
# Epoch 151/300, Train Loss: 0.4044, Train Accuracy: 83.80%, Validation Loss: 0.7819, Validation Accuracy: 71.94%
# Epoch 152/300, Train Loss: 0.3932, Train Accuracy: 84.18%, Validation Loss: 0.8001, Validation Accuracy: 71.65%
# Epoch 153/300, Train Loss: 0.4177, Train Accuracy: 83.27%, Validation Loss: 0.7661, Validation Accuracy: 71.94%
# Epoch 154/300, Train Loss: 0.4172, Train Accuracy: 83.43%, Validation Loss: 0.7962, Validation Accuracy: 71.26%
# Epoch 155/300, Train Loss: 0.4119, Train Accuracy: 83.00%, Validation Loss: 0.7718, Validation Accuracy: 71.84%
# Epoch 156/300, Train Loss: 0.3943, Train Accuracy: 84.18%, Validation Loss: 0.7777, Validation Accuracy: 72.13%
# Epoch 157/300, Train Loss: 0.4143, Train Accuracy: 83.53%, Validation Loss: 0.7989, Validation Accuracy: 70.97%
# Epoch 158/300, Train Loss: 0.4100, Train Accuracy: 83.92%, Validation Loss: 0.8208, Validation Accuracy: 69.72%
# Epoch 159/300, Train Loss: 0.4167, Train Accuracy: 83.31%, Validation Loss: 0.7751, Validation Accuracy: 72.32%
# Epoch 160/300, Train Loss: 0.4081, Train Accuracy: 83.53%, Validation Loss: 0.7897, Validation Accuracy: 71.84%
# Epoch 161/300, Train Loss: 0.4113, Train Accuracy: 83.00%, Validation Loss: 0.7852, Validation Accuracy: 71.46%
# Epoch 162/300, Train Loss: 0.3987, Train Accuracy: 84.28%, Validation Loss: 0.7747, Validation Accuracy: 71.84%
# Epoch 163/300, Train Loss: 0.3966, Train Accuracy: 84.52%, Validation Loss: 0.7528, Validation Accuracy: 74.54%
# Epoch 164/300, Train Loss: 0.3838, Train Accuracy: 84.52%, Validation Loss: 0.7524, Validation Accuracy: 72.81%
# Epoch 165/300, Train Loss: 0.3863, Train Accuracy: 85.05%, Validation Loss: 0.7440, Validation Accuracy: 72.71%
# Epoch 166/300, Train Loss: 0.3764, Train Accuracy: 84.66%, Validation Loss: 0.7643, Validation Accuracy: 73.96%
# Epoch 167/300, Train Loss: 0.3733, Train Accuracy: 85.63%, Validation Loss: 0.7548, Validation Accuracy: 73.00%
# Epoch 168/300, Train Loss: 0.3802, Train Accuracy: 84.83%, Validation Loss: 0.7611, Validation Accuracy: 72.42%
# Epoch 169/300, Train Loss: 0.3728, Train Accuracy: 84.88%, Validation Loss: 0.7743, Validation Accuracy: 73.00%
# Epoch 170/300, Train Loss: 0.3643, Train Accuracy: 85.31%, Validation Loss: 0.7542, Validation Accuracy: 74.25%
# Epoch 171/300, Train Loss: 0.3633, Train Accuracy: 86.09%, Validation Loss: 0.7765, Validation Accuracy: 73.58%
# Epoch 172/300, Train Loss: 0.3561, Train Accuracy: 86.13%, Validation Loss: 0.7537, Validation Accuracy: 73.87%
# Epoch 173/300, Train Loss: 0.3499, Train Accuracy: 86.47%, Validation Loss: 0.7526, Validation Accuracy: 73.19%
# Epoch 174/300, Train Loss: 0.3513, Train Accuracy: 85.99%, Validation Loss: 0.7725, Validation Accuracy: 72.52%
# Epoch 175/300, Train Loss: 0.3492, Train Accuracy: 86.62%, Validation Loss: 0.7620, Validation Accuracy: 73.19%
# Epoch 176/300, Train Loss: 0.3607, Train Accuracy: 85.53%, Validation Loss: 0.7639, Validation Accuracy: 72.81%
# Epoch 177/300, Train Loss: 0.3660, Train Accuracy: 85.72%, Validation Loss: 0.7863, Validation Accuracy: 72.90%
# Epoch 178/300, Train Loss: 0.3588, Train Accuracy: 85.70%, Validation Loss: 0.7491, Validation Accuracy: 74.06%
# Epoch 179/300, Train Loss: 0.3639, Train Accuracy: 85.31%, Validation Loss: 0.7640, Validation Accuracy: 73.87%
# Epoch 180/300, Train Loss: 0.3540, Train Accuracy: 86.40%, Validation Loss: 0.7825, Validation Accuracy: 73.48%
# Epoch 181/300, Train Loss: 0.3355, Train Accuracy: 86.91%, Validation Loss: 0.7853, Validation Accuracy: 73.48%
# Epoch 182/300, Train Loss: 0.3511, Train Accuracy: 86.40%, Validation Loss: 0.7703, Validation Accuracy: 73.10%
# Epoch 183/300, Train Loss: 0.3517, Train Accuracy: 86.23%, Validation Loss: 0.7887, Validation Accuracy: 73.67%
# Epoch 184/300, Train Loss: 0.3625, Train Accuracy: 85.51%, Validation Loss: 0.7884, Validation Accuracy: 73.87%
# Epoch 185/300, Train Loss: 0.3537, Train Accuracy: 85.97%, Validation Loss: 0.7874, Validation Accuracy: 74.16%
# Epoch 186/300, Train Loss: 0.3353, Train Accuracy: 86.88%, Validation Loss: 0.7901, Validation Accuracy: 73.87%
# Epoch 187/300, Train Loss: 0.3432, Train Accuracy: 85.89%, Validation Loss: 0.7741, Validation Accuracy: 72.52%
# Epoch 188/300, Train Loss: 0.3344, Train Accuracy: 86.40%, Validation Loss: 0.7678, Validation Accuracy: 73.19%
# Epoch 189/300, Train Loss: 0.3564, Train Accuracy: 85.89%, Validation Loss: 0.7640, Validation Accuracy: 73.29%
# Epoch 190/300, Train Loss: 0.3520, Train Accuracy: 86.38%, Validation Loss: 0.8034, Validation Accuracy: 72.61%
# Epoch 191/300, Train Loss: 0.3324, Train Accuracy: 87.17%, Validation Loss: 0.7854, Validation Accuracy: 73.58%
# Epoch 192/300, Train Loss: 0.3352, Train Accuracy: 87.32%, Validation Loss: 0.7738, Validation Accuracy: 73.29%
# Epoch 193/300, Train Loss: 0.3409, Train Accuracy: 86.16%, Validation Loss: 0.7949, Validation Accuracy: 73.00%
# Epoch 194/300, Train Loss: 0.3280, Train Accuracy: 87.24%, Validation Loss: 0.7782, Validation Accuracy: 74.06%
# Epoch 195/300, Train Loss: 0.3346, Train Accuracy: 87.10%, Validation Loss: 0.8069, Validation Accuracy: 72.90%
# Epoch 196/300, Train Loss: 0.3473, Train Accuracy: 85.92%, Validation Loss: 0.8013, Validation Accuracy: 72.61%
# Epoch 197/300, Train Loss: 0.3420, Train Accuracy: 86.76%, Validation Loss: 0.7989, Validation Accuracy: 72.61%
# Epoch 198/300, Train Loss: 0.3375, Train Accuracy: 86.76%, Validation Loss: 0.7849, Validation Accuracy: 73.77%
# Epoch 199/300, Train Loss: 0.3257, Train Accuracy: 87.58%, Validation Loss: 0.7703, Validation Accuracy: 73.77%
# Epoch 200/300, Train Loss: 0.3218, Train Accuracy: 87.61%, Validation Loss: 0.7802, Validation Accuracy: 73.38%
# Epoch 201/300, Train Loss: 0.3331, Train Accuracy: 86.81%, Validation Loss: 0.8102, Validation Accuracy: 72.03%
# Epoch 202/300, Train Loss: 0.3462, Train Accuracy: 86.74%, Validation Loss: 0.7835, Validation Accuracy: 72.42%
# Epoch 203/300, Train Loss: 0.3526, Train Accuracy: 86.38%, Validation Loss: 0.7665, Validation Accuracy: 73.77%
# Epoch 204/300, Train Loss: 0.3302, Train Accuracy: 87.24%, Validation Loss: 0.7782, Validation Accuracy: 72.90%
# Epoch 205/300, Train Loss: 0.3258, Train Accuracy: 87.24%, Validation Loss: 0.7861, Validation Accuracy: 74.16%
# Epoch 206/300, Train Loss: 0.3277, Train Accuracy: 86.59%, Validation Loss: 0.7761, Validation Accuracy: 73.77%
# Epoch 207/300, Train Loss: 0.3311, Train Accuracy: 87.22%, Validation Loss: 0.7777, Validation Accuracy: 74.06%
# Epoch 208/300, Train Loss: 0.3230, Train Accuracy: 87.29%, Validation Loss: 0.7875, Validation Accuracy: 73.58%
# Epoch 209/300, Train Loss: 0.3274, Train Accuracy: 87.65%, Validation Loss: 0.7764, Validation Accuracy: 73.87%
# Epoch 210/300, Train Loss: 0.3292, Train Accuracy: 87.29%, Validation Loss: 0.7846, Validation Accuracy: 73.96%
# Epoch 211/300, Train Loss: 0.3317, Train Accuracy: 87.36%, Validation Loss: 0.7824, Validation Accuracy: 74.54%
# Epoch 212/300, Train Loss: 0.3015, Train Accuracy: 88.62%, Validation Loss: 0.7577, Validation Accuracy: 74.54%
# Epoch 213/300, Train Loss: 0.2958, Train Accuracy: 88.93%, Validation Loss: 0.7637, Validation Accuracy: 75.02%
# Epoch 214/300, Train Loss: 0.3017, Train Accuracy: 88.30%, Validation Loss: 0.7689, Validation Accuracy: 73.29%
# Epoch 215/300, Train Loss: 0.3032, Train Accuracy: 88.30%, Validation Loss: 0.7750, Validation Accuracy: 74.54%
# Epoch 216/300, Train Loss: 0.2945, Train Accuracy: 88.76%, Validation Loss: 0.7823, Validation Accuracy: 73.29%
# Epoch 217/300, Train Loss: 0.3015, Train Accuracy: 88.28%, Validation Loss: 0.7752, Validation Accuracy: 74.54%
# Epoch 218/300, Train Loss: 0.3081, Train Accuracy: 88.26%, Validation Loss: 0.7776, Validation Accuracy: 74.16%
# Epoch 219/300, Train Loss: 0.3069, Train Accuracy: 87.99%, Validation Loss: 0.7700, Validation Accuracy: 73.77%
# Epoch 220/300, Train Loss: 0.3038, Train Accuracy: 87.87%, Validation Loss: 0.7737, Validation Accuracy: 74.06%
# Epoch 221/300, Train Loss: 0.2985, Train Accuracy: 88.64%, Validation Loss: 0.7815, Validation Accuracy: 75.02%
# Epoch 222/300, Train Loss: 0.3030, Train Accuracy: 88.64%, Validation Loss: 0.7991, Validation Accuracy: 74.06%
# Epoch 223/300, Train Loss: 0.3168, Train Accuracy: 87.27%, Validation Loss: 0.7829, Validation Accuracy: 73.38%
# Epoch 224/300, Train Loss: 0.2927, Train Accuracy: 88.84%, Validation Loss: 0.7785, Validation Accuracy: 74.16%
# Epoch 225/300, Train Loss: 0.3066, Train Accuracy: 87.89%, Validation Loss: 0.7723, Validation Accuracy: 72.90%
# Epoch 226/300, Train Loss: 0.2916, Train Accuracy: 88.06%, Validation Loss: 0.7762, Validation Accuracy: 74.25%
# Epoch 227/300, Train Loss: 0.2988, Train Accuracy: 88.45%, Validation Loss: 0.7845, Validation Accuracy: 72.81%
# Epoch 228/300, Train Loss: 0.2983, Train Accuracy: 88.74%, Validation Loss: 0.8060, Validation Accuracy: 73.87%
# Epoch 229/300, Train Loss: 0.3071, Train Accuracy: 88.26%, Validation Loss: 0.7981, Validation Accuracy: 73.96%
# Epoch 230/300, Train Loss: 0.3051, Train Accuracy: 88.40%, Validation Loss: 0.7914, Validation Accuracy: 73.77%
# Epoch 231/300, Train Loss: 0.2956, Train Accuracy: 88.64%, Validation Loss: 0.7714, Validation Accuracy: 73.87%
# Epoch 232/300, Train Loss: 0.2933, Train Accuracy: 88.64%, Validation Loss: 0.7746, Validation Accuracy: 74.93%
# Epoch 233/300, Train Loss: 0.3001, Train Accuracy: 88.47%, Validation Loss: 0.7953, Validation Accuracy: 72.81%
# Epoch 234/300, Train Loss: 0.3131, Train Accuracy: 87.94%, Validation Loss: 0.7805, Validation Accuracy: 73.87%
# Epoch 235/300, Train Loss: 0.2977, Train Accuracy: 88.67%, Validation Loss: 0.7813, Validation Accuracy: 74.25%
# Epoch 236/300, Train Loss: 0.3063, Train Accuracy: 88.06%, Validation Loss: 0.7669, Validation Accuracy: 74.25%
# Epoch 237/300, Train Loss: 0.3115, Train Accuracy: 87.82%, Validation Loss: 0.7946, Validation Accuracy: 72.61%
# Epoch 238/300, Train Loss: 0.2736, Train Accuracy: 89.51%, Validation Loss: 0.7669, Validation Accuracy: 73.19%
# Epoch 239/300, Train Loss: 0.2822, Train Accuracy: 89.29%, Validation Loss: 0.7893, Validation Accuracy: 73.19%
# Epoch 240/300, Train Loss: 0.2913, Train Accuracy: 89.05%, Validation Loss: 0.7853, Validation Accuracy: 73.19%
# Epoch 241/300, Train Loss: 0.3057, Train Accuracy: 88.06%, Validation Loss: 0.7822, Validation Accuracy: 73.38%
# Epoch 242/300, Train Loss: 0.2918, Train Accuracy: 89.17%, Validation Loss: 0.7686, Validation Accuracy: 73.29%
# Epoch 243/300, Train Loss: 0.2902, Train Accuracy: 88.18%, Validation Loss: 0.7860, Validation Accuracy: 73.10%
# Epoch 244/300, Train Loss: 0.2777, Train Accuracy: 89.68%, Validation Loss: 0.7891, Validation Accuracy: 73.29%
# Epoch 245/300, Train Loss: 0.2840, Train Accuracy: 89.25%, Validation Loss: 0.7766, Validation Accuracy: 73.77%
# Epoch 246/300, Train Loss: 0.2821, Train Accuracy: 89.17%, Validation Loss: 0.7785, Validation Accuracy: 73.67%
# Epoch 247/300, Train Loss: 0.2909, Train Accuracy: 88.30%, Validation Loss: 0.7792, Validation Accuracy: 74.25%
# Epoch 248/300, Train Loss: 0.2748, Train Accuracy: 89.32%, Validation Loss: 0.7872, Validation Accuracy: 73.67%
# Epoch 249/300, Train Loss: 0.2917, Train Accuracy: 89.17%, Validation Loss: 0.7707, Validation Accuracy: 73.58%
# Epoch 250/300, Train Loss: 0.2767, Train Accuracy: 89.41%, Validation Loss: 0.7737, Validation Accuracy: 73.48%
# Epoch 251/300, Train Loss: 0.2904, Train Accuracy: 88.76%, Validation Loss: 0.7810, Validation Accuracy: 74.06%
# Epoch 252/300, Train Loss: 0.2868, Train Accuracy: 88.69%, Validation Loss: 0.7737, Validation Accuracy: 73.96%
# Epoch 253/300, Train Loss: 0.2771, Train Accuracy: 89.29%, Validation Loss: 0.7867, Validation Accuracy: 74.06%
# Epoch 254/300, Train Loss: 0.2916, Train Accuracy: 88.84%, Validation Loss: 0.7688, Validation Accuracy: 73.77%
# Epoch 255/300, Train Loss: 0.2774, Train Accuracy: 89.12%, Validation Loss: 0.7745, Validation Accuracy: 74.06%
# Epoch 256/300, Train Loss: 0.2857, Train Accuracy: 89.12%, Validation Loss: 0.7916, Validation Accuracy: 72.90%
# Epoch 257/300, Train Loss: 0.2777, Train Accuracy: 89.63%, Validation Loss: 0.7843, Validation Accuracy: 73.58%
# Epoch 258/300, Train Loss: 0.2796, Train Accuracy: 89.39%, Validation Loss: 0.7734, Validation Accuracy: 74.35%
# Epoch 259/300, Train Loss: 0.2727, Train Accuracy: 89.63%, Validation Loss: 0.7796, Validation Accuracy: 74.25%
# Epoch 260/300, Train Loss: 0.2878, Train Accuracy: 89.20%, Validation Loss: 0.7813, Validation Accuracy: 73.96%
# Epoch 261/300, Train Loss: 0.2818, Train Accuracy: 89.39%, Validation Loss: 0.7753, Validation Accuracy: 74.16%
# Epoch 262/300, Train Loss: 0.2809, Train Accuracy: 88.96%, Validation Loss: 0.7700, Validation Accuracy: 74.64%
# Epoch 263/300, Train Loss: 0.2817, Train Accuracy: 89.85%, Validation Loss: 0.7736, Validation Accuracy: 74.06%
# Epoch 264/300, Train Loss: 0.2763, Train Accuracy: 89.22%, Validation Loss: 0.7751, Validation Accuracy: 74.54%
# Epoch 265/300, Train Loss: 0.2625, Train Accuracy: 90.07%, Validation Loss: 0.7801, Validation Accuracy: 74.25%
# Epoch 266/300, Train Loss: 0.2767, Train Accuracy: 89.15%, Validation Loss: 0.7837, Validation Accuracy: 74.83%
# Epoch 267/300, Train Loss: 0.2719, Train Accuracy: 89.58%, Validation Loss: 0.7733, Validation Accuracy: 74.64%
# Epoch 268/300, Train Loss: 0.2725, Train Accuracy: 89.05%, Validation Loss: 0.7871, Validation Accuracy: 74.54%
# Epoch 269/300, Train Loss: 0.2727, Train Accuracy: 89.49%, Validation Loss: 0.7846, Validation Accuracy: 74.06%
# Epoch 270/300, Train Loss: 0.2614, Train Accuracy: 89.99%, Validation Loss: 0.7804, Validation Accuracy: 73.96%
# Epoch 271/300, Train Loss: 0.2936, Train Accuracy: 88.47%, Validation Loss: 0.7783, Validation Accuracy: 73.87%
# Epoch 272/300, Train Loss: 0.2802, Train Accuracy: 89.25%, Validation Loss: 0.7768, Validation Accuracy: 74.16%
# Epoch 273/300, Train Loss: 0.2756, Train Accuracy: 89.46%, Validation Loss: 0.7829, Validation Accuracy: 74.35%
# Epoch 274/300, Train Loss: 0.2705, Train Accuracy: 90.09%, Validation Loss: 0.7789, Validation Accuracy: 74.45%
# Epoch 275/300, Train Loss: 0.2799, Train Accuracy: 89.17%, Validation Loss: 0.7902, Validation Accuracy: 73.77%
# Epoch 276/300, Train Loss: 0.2687, Train Accuracy: 89.80%, Validation Loss: 0.7856, Validation Accuracy: 73.67%
# Epoch 277/300, Train Loss: 0.2731, Train Accuracy: 89.90%, Validation Loss: 0.7843, Validation Accuracy: 74.35%
# Epoch 278/300, Train Loss: 0.2653, Train Accuracy: 89.87%, Validation Loss: 0.7791, Validation Accuracy: 74.45%
# Epoch 279/300, Train Loss: 0.2737, Train Accuracy: 89.10%, Validation Loss: 0.7826, Validation Accuracy: 73.87%
# Epoch 280/300, Train Loss: 0.2802, Train Accuracy: 89.20%, Validation Loss: 0.7843, Validation Accuracy: 74.16%
# Epoch 281/300, Train Loss: 0.2836, Train Accuracy: 89.39%, Validation Loss: 0.7905, Validation Accuracy: 73.67%
# Epoch 282/300, Train Loss: 0.2859, Train Accuracy: 89.10%, Validation Loss: 0.7828, Validation Accuracy: 74.16%
# Epoch 283/300, Train Loss: 0.2759, Train Accuracy: 89.08%, Validation Loss: 0.7766, Validation Accuracy: 74.45%
# Epoch 284/300, Train Loss: 0.2756, Train Accuracy: 89.22%, Validation Loss: 0.7763, Validation Accuracy: 74.25%
# Epoch 285/300, Train Loss: 0.2724, Train Accuracy: 89.56%, Validation Loss: 0.7807, Validation Accuracy: 74.35%
# Epoch 286/300, Train Loss: 0.2786, Train Accuracy: 89.78%, Validation Loss: 0.7830, Validation Accuracy: 74.25%
# Epoch 287/300, Train Loss: 0.2886, Train Accuracy: 88.74%, Validation Loss: 0.7869, Validation Accuracy: 74.45%
# Epoch 288/300, Train Loss: 0.2712, Train Accuracy: 89.12%, Validation Loss: 0.7836, Validation Accuracy: 73.87%
# Epoch 289/300, Train Loss: 0.2820, Train Accuracy: 89.12%, Validation Loss: 0.7827, Validation Accuracy: 74.25%
# Epoch 290/300, Train Loss: 0.2695, Train Accuracy: 89.75%, Validation Loss: 0.7747, Validation Accuracy: 74.54%
# Epoch 291/300, Train Loss: 0.2729, Train Accuracy: 89.44%, Validation Loss: 0.7887, Validation Accuracy: 74.35%
# Epoch 292/300, Train Loss: 0.2823, Train Accuracy: 89.37%, Validation Loss: 0.7786, Validation Accuracy: 74.54%
# Epoch 293/300, Train Loss: 0.3070, Train Accuracy: 87.82%, Validation Loss: 0.7806, Validation Accuracy: 74.45%
# Epoch 294/300, Train Loss: 0.2825, Train Accuracy: 88.52%, Validation Loss: 0.7867, Validation Accuracy: 74.06%
# Epoch 295/300, Train Loss: 0.2706, Train Accuracy: 89.58%, Validation Loss: 0.7943, Validation Accuracy: 73.87%
# Epoch 296/300, Train Loss: 0.2688, Train Accuracy: 89.46%, Validation Loss: 0.7747, Validation Accuracy: 74.35%
# Epoch 297/300, Train Loss: 0.2846, Train Accuracy: 89.15%, Validation Loss: 0.7736, Validation Accuracy: 74.64%
# Epoch 298/300, Train Loss: 0.2753, Train Accuracy: 89.41%, Validation Loss: 0.7791, Validation Accuracy: 74.45%
# Epoch 299/300, Train Loss: 0.2748, Train Accuracy: 89.46%, Validation Loss: 0.7802, Validation Accuracy: 74.16%
# Epoch 300/300, Train Loss: 0.2580, Train Accuracy: 89.97%, Validation Loss: 0.7795, Validation Accuracy: 74.16%
# Average Loss: 0.25804455715229574
# Highest Train Accuracy: 0.9008922112370388

# %%
classes_list = ['Left', 'Right', 'Foot', 'Tongue']
eval_model = EvalModel(trained_cnn_gru_model)

# %%
# Testing the model
accuracy, y_true, y_pred = eval_model.test_model(test_dataset)
# Out:
# /------------------------------/
# Test Accuracy: 74.16%
# /------------------------------/

# %%
# Classification report
eval_model.print_classification_report(y_true, y_pred, classes_list)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Left       0.72      0.76      0.74       259
#        Right       0.78      0.74      0.76       259
#         Foot       0.77      0.72      0.75       260
#       Tongue       0.70      0.75      0.72       259
#
#     accuracy                           0.74      1037
#    macro avg       0.74      0.74      0.74      1037
# weighted avg       0.74      0.74      0.74      1037

# %%
# Plot confusion matrix
eval_model.plot_confusion_matrix(y_true, y_pred, classes_list)

# %%
# Plot classification metrics like precision, recall, and f1-score
eval_model.plot_classification_metrics(y_true, y_pred, classes_list)
# Out:
# Cohen's Kappa: 0.6554

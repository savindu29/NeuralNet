# %% [markdown]
# <a href="https://colab.research.google.com/github/savindu29/NeuralNet/blob/main/cnn_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install torch-summary

# %%
import math
import copy
import gdown
import random
import scipy.io
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt


# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import os

# Mount Google Drive (only for Colab users)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_save_path = "/content/drive/MyDrive/Preprocessed_Data"
# Define separate paths for NumPy and PyTorch tensors
numpy_save_path = os.path.join(root_save_path, "numpy_data")
torch_save_path = os.path.join(root_save_path, "torch_data")

# %%
# Load NumPy arrays
X_train = np.load(os.path.join(numpy_save_path, "X_train.npy"))
X_test = np.load(os.path.join(numpy_save_path, "X_test.npy"))
y_train = np.load(os.path.join(numpy_save_path, "y_train.npy"))
y_test = np.load(os.path.join(numpy_save_path, "y_test.npy"))

# Print loaded shapes
print("Loaded NumPy Data:")
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# Choosing Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1).to(device)  # Add missing dimension
X_test_tensor = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1).to(device)
y_train_tensor = torch.tensor(y_train, dtype=torch.long).to(device)
y_test_tensor = torch.tensor(y_test, dtype=torch.long).to(device)

# Create Tensor Dataset
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# Print dataset sizes
print("\nProcessed PyTorch Tensors:")
print("X_train shape:", X_train_tensor.size())
print("X_test shape:", X_test_tensor.size())
print("y_train shape:", y_train_tensor.size())
print("y_test shape:", y_test_tensor.size())

print("✅ Data successfully loaded and processed!")
# Out:
# Loaded NumPy Data:
# X_train shape: (4147, 22, 1001)
# X_test shape: (1037, 22, 1001)
# y_train shape: (4147,)
# y_test shape: (1037,)
#
# Processed PyTorch Tensors:
# X_train shape: torch.Size([4147, 1, 22, 1001])
# X_test shape: torch.Size([1037, 1, 22, 1001])
# y_train shape: torch.Size([4147])
# y_test shape: torch.Size([1037])
# ✅ Data successfully loaded and processed!

# %% [markdown]
# # Model Training class

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import numpy as np
import matplotlib.pyplot as plt

class TrainModel():
    def __init__(self, patience=10):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.train_loss = []  # To store training loss for plotting
        self.train_accuracy = []  # To store training accuracy for plotting
        self.val_loss = []  # To store validation loss for plotting
        self.val_accuracy = []  # To store validation accuracy for plotting

    def train_model(self, model, train_dataset, validation_dataset=None, learning_rate=0.001, batch_size=64, epochs=500):
        # Send the model to the device (GPU or CPU)
        model = model.to(self.device)

        # Loss function and optimizer
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # Initialize the ReduceLROnPlateau scheduler
        scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=10, factor=0.5, verbose=True)

        # Create DataLoader for training data
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        # Track highest accuracy and patience for Early Stopping
        highest_train_accuracy = 0.0
        best_epoch = 0
        early_stopping_counter = 0

        for epoch in range(epochs):
            model.train()  # Set the model to training mode
            running_loss = 0.0
            correct = 0
            total = 0

            # Training loop
            for inputs, labels in train_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                optimizer.zero_grad()  # Zero the gradients

                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Backward pass and optimization
                loss.backward()
                optimizer.step()

                # Track running loss and accuracy
                running_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            # Calculate epoch loss and accuracy
            epoch_loss = running_loss / len(train_loader.dataset)
            epoch_accuracy = correct / total

            # Update the learning rate scheduler based on training loss
            scheduler.step(epoch_loss)  # Reduce learning rate if loss doesn't improve

            # Collect the data for plotting
            self.train_loss.append(epoch_loss)
            self.train_accuracy.append(epoch_accuracy)

            # Validation step
            if validation_dataset is not None:
                val_loss, val_accuracy = self.validate_model(model, validation_dataset, criterion)
                self.val_loss.append(val_loss)
                self.val_accuracy.append(val_accuracy)

                print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {(epoch_accuracy*100):.2f}%, "
                      f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy*100:.2f}%")
            else:
                print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {(epoch_accuracy*100):.2f}%")

            # Early stopping
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy
                best_epoch = epoch
            #     early_stopping_counter = 0  # Reset the early stopping counter
            # else:
            #     early_stopping_counter += 1  # Increment the counter if no improvement

            # # Check for early stopping
            # if early_stopping_counter >= self.patience:
            #     print("Early stopping triggered")
            #     break

        # Calculate the average training loss over all epochs
        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)
        print("Highest Train Accuracy:", highest_train_accuracy)

        # Saving the trained model
        torch.save(model.state_dict(), 'trained_model.pth')

        # Plotting the results
        self.plot_results()

        return model

    def validate_model(self, model, validation_dataset, criterion):
        """Validation step to monitor the validation performance."""
        model.eval()  # Set the model to evaluation mode
        val_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)

        val_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():  # No need to track gradients during validation
            for inputs, labels in val_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        # Calculate validation loss and accuracy
        val_loss = val_loss / len(validation_dataset)
        val_accuracy = correct_val / total_val
        return val_loss, val_accuracy

    def plot_results(self):
        """Plot training and validation loss and accuracy."""
        epochs = len(self.train_loss)

        plt.figure(figsize=(10, 6))

        # Plot accuracy
        plt.subplot(1, 2, 1)
        plt.plot(range(epochs), self.train_accuracy, label='accuracy', color='blue')
        plt.plot(range(epochs), self.val_accuracy, label='val_accuracy', color='blue', linestyle='dotted')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy vs Epochs')
        plt.legend()

        # Plot loss
        plt.subplot(1, 2, 2)
        plt.plot(range(epochs), self.train_loss, label='loss', color='red')
        plt.plot(range(epochs), self.val_loss, label='val_loss', color='red', linestyle='dotted')
        plt.xlabel('Epochs')
        plt.ylabel('Loss (cross-entropy)')
        plt.title('Loss vs Epochs')
        plt.legend()

        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Model Evaluation class

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, cohen_kappa_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class EvalModel():
    def __init__(self, model):
        self.model = model.to(device)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def test_model(self, test_dataset):
        self.model.eval()
        correct = 0
        total = 0
        test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
        y_true = []
        y_pred = []

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())

        accuracy = (correct / total) * 100
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")

        return accuracy, y_true, y_pred

    def print_classification_report(self, y_true, y_pred, target_names):
        print("Classification Report:\n")
        report = classification_report(y_true, y_pred, target_names=target_names)
        print(report)

    def plot_confusion_matrix(self, y_true, y_pred, classes):
        cf_matrix = confusion_matrix(y_true, y_pred)
        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        plt.figure(figsize=(10, 7))
        sns.heatmap(df_cm, annot=True, cmap='Blues', fmt='d')  # 'd' ensures actual counts, not percentages
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.savefig('confusion_matrix_model.png')
        plt.show()


    def plot_metrics(self, hist):
        # Plot accuracy and loss
        fig, ax = plt.subplots()
        ax.plot(hist['accuracy'], color='b', label='accuracy')
        ax.plot(hist['val_accuracy'], linestyle=':', color='b', label='val_accuracy')
        ax.set_ylabel("Accuracy", color='b')
        ax.set_ylim([0, 1])

        ax2 = ax.twinx()
        ax2.plot(hist['loss'], color='r', label='loss')
        ax2.plot(hist['val_loss'], linestyle=':', color='r', label='val_loss')
        ax2.set_ylabel("Loss (cross-entropy)", color='r')

        fig.legend(loc='best')
        plt.title('Accuracy and Loss over Epochs')
        plt.show()

    def plot_classification_metrics(self, y_true, y_pred, target_names):
        # Classification report and metrics
        report = classification_report(y_true, y_pred, target_names=target_names, output_dict=True)
        report_df = pd.DataFrame(report).transpose()

        # Plot metrics
        report_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(10, 7))
        plt.title('Classification Report Metrics')
        plt.xlabel('Classes')
        plt.ylabel('Scores')
        plt.legend(loc='lower right')
        plt.show()

        # Plot Cohen's Kappa score
        kappa = cohen_kappa_score(y_true, y_pred)
        print(f"Cohen's Kappa: {kappa:.4f}")

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn

class CNN_LSTM(nn.Module):  # EEGNet with 2D CNN + LSTM
    def __init__(self, chans=22, classes=4, time_points=1001, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, lstm_hidden_size=128,
                 lstm_layers=2, dropout_rate=0.5, max_norm1=1, max_norm2=0.25):
        super(CNN_LSTM, self).__init__()
        # Calculating the number of features after CNN layers for LSTM input
        linear_size = (time_points // (pk1 * pk2)) * f2

        # Temporal Filters
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )

        # Spatial Filters
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False),  # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )

        # Separable and Pointwise Convolutions
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16), groups=f2, bias=False, padding='same'),  # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False),  # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )

        # Flatten and reshape to feed into LSTM
        self.flatten = nn.Flatten()

        # LSTM for temporal context learning
        self.lstm = nn.LSTM(input_size=linear_size, hidden_size=lstm_hidden_size, num_layers=lstm_layers,
                            batch_first=True, dropout=dropout_rate, bidirectional=True)

        # Fully connected layer
        self.fc = nn.Linear(2 * lstm_hidden_size, classes)  # Bidirectional LSTM doubles hidden size

        # Apply max_norm constraint to the depthwise layer in block2
        self._apply_max_norm(self.block2[0], max_norm1)

        # Apply max_norm constraint to the linear layer
        self._apply_max_norm(self.fc, max_norm2)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.flatten(x)

        # Reshape for LSTM input: (batch_size, sequence_length, features)
        batch_size = x.size(0)
        x = x.view(batch_size, -1, x.size(1))

        # Pass through LSTM
        lstm_out, _ = self.lstm(x)
        lstm_out = lstm_out[:, -1, :]  # Take the output of the last time step

        # Final classification
        x = self.fc(lstm_out)
        return x

# %% [markdown]
# # Summary

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Model Parameters
chans = 22
classes = 4
time_points = 1001
f1 = 32  # Number of filters for the first convolutional layer
f2 = 64  # Number of filters for the second convolutional layer
lstm_hidden_size = 64  # Reduce hidden size to prevent overfitting
dropout_rate = 0.5  # Increase dropout for regularization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Correcting the class instantiation
improved_model = CNN_LSTM(
    chans=chans, classes=classes, time_points=time_points,
    f1=f1, f2=f2, dropout_rate=dropout_rate
).to(device)

# Display the summary of the model
summary(improved_model, input_size=(1, chans, time_points))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,024
# |    └─BatchNorm2d: 2-2                  64
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       1,408
# |    └─BatchNorm2d: 2-4                  128
# |    └─ELU: 2-5                          --
# |    └─AvgPool2d: 2-6                    --
# |    └─Dropout: 2-7                      --
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-8                       1,024
# |    └─Conv2d: 2-9                       4,096
# |    └─BatchNorm2d: 2-10                 128
# |    └─ELU: 2-11                         --
# |    └─AvgPool2d: 2-12                   --
# |    └─Dropout: 2-13                     --
# ├─Flatten: 1-4                           --
# ├─LSTM: 1-5                              987,136
# ├─Linear: 1-6                            1,028
# =================================================================
# Total params: 996,036
# Trainable params: 996,036
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Sequential: 1-1                        --
# |    └─Conv2d: 2-1                       1,024
# |    └─BatchNorm2d: 2-2                  64
# ├─Sequential: 1-2                        --
# |    └─Conv2d: 2-3                       1,408
# |    └─BatchNorm2d: 2-4                  128
# |    └─ELU: 2-5                          --
# |    └─AvgPool2d: 2-6                    --
# |    └─Dropout: 2-7                      --
# ├─Sequential: 1-3                        --
# |    └─Conv2d: 2-8                       1,024
# |    └─Conv2d: 2-9                       4,096
# |    └─BatchNorm2d: 2-10                 128
# |    └─ELU: 2-11                         --
# |    └─AvgPool2d: 2-12                   --
# |    └─Dropout: 2-13                     --
# ├─Flatten: 1-4                           --
# ├─LSTM: 1-5                              987,136
# ├─Linear: 1-6                            1,028
# =================================================================
# Total params: 996,036
# Trainable params: 996,036
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Train the model

# %%
# Training Hyperparameters
EPOCHS = 300
BATCH_SIZE = 64
LEARNING_RATE = 0.001
trainer = TrainModel(patience=10)
trained_cnn_lstm_model = trainer.train_model(improved_model, train_dataset, validation_dataset=test_dataset,learning_rate=LEARNING_RATE,
                                   batch_size=BATCH_SIZE, epochs=EPOCHS)
torch.save(trained_cnn_lstm_model.state_dict(), 'cnn_lstm_model.pth')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1036.)
#   return F.conv2d(
# Epoch 1/300, Train Loss: 1.3719, Train Accuracy: 28.02%, Validation Loss: 1.3232, Validation Accuracy: 33.75%
# Epoch 2/300, Train Loss: 1.3153, Train Accuracy: 34.68%, Validation Loss: 1.2805, Validation Accuracy: 35.49%
# Epoch 3/300, Train Loss: 1.2808, Train Accuracy: 38.12%, Validation Loss: 1.2350, Validation Accuracy: 41.08%
# Epoch 4/300, Train Loss: 1.2227, Train Accuracy: 41.81%, Validation Loss: 1.1418, Validation Accuracy: 46.09%
# Epoch 5/300, Train Loss: 1.1862, Train Accuracy: 44.42%, Validation Loss: 1.1053, Validation Accuracy: 50.53%
# Epoch 6/300, Train Loss: 1.1458, Train Accuracy: 46.49%, Validation Loss: 1.0897, Validation Accuracy: 50.34%
# Epoch 7/300, Train Loss: 1.1290, Train Accuracy: 46.88%, Validation Loss: 1.0681, Validation Accuracy: 49.76%
# Epoch 8/300, Train Loss: 1.1029, Train Accuracy: 49.29%, Validation Loss: 1.0530, Validation Accuracy: 51.78%
# Epoch 9/300, Train Loss: 1.1046, Train Accuracy: 48.71%, Validation Loss: 1.0406, Validation Accuracy: 53.81%
# Epoch 10/300, Train Loss: 1.0742, Train Accuracy: 50.40%, Validation Loss: 1.0604, Validation Accuracy: 49.47%
# Epoch 11/300, Train Loss: 1.0529, Train Accuracy: 52.54%, Validation Loss: 1.0016, Validation Accuracy: 54.58%
# Epoch 12/300, Train Loss: 1.0372, Train Accuracy: 53.00%, Validation Loss: 1.0072, Validation Accuracy: 53.52%
# Epoch 13/300, Train Loss: 1.0353, Train Accuracy: 53.53%, Validation Loss: 0.9949, Validation Accuracy: 54.29%
# Epoch 14/300, Train Loss: 1.0226, Train Accuracy: 53.77%, Validation Loss: 0.9779, Validation Accuracy: 53.81%
# Epoch 15/300, Train Loss: 1.0106, Train Accuracy: 54.64%, Validation Loss: 0.9941, Validation Accuracy: 54.19%
# Epoch 16/300, Train Loss: 0.9915, Train Accuracy: 55.37%, Validation Loss: 0.9672, Validation Accuracy: 56.03%
# Epoch 17/300, Train Loss: 0.9936, Train Accuracy: 55.94%, Validation Loss: 0.9758, Validation Accuracy: 55.26%
# Epoch 18/300, Train Loss: 0.9788, Train Accuracy: 55.92%, Validation Loss: 0.9389, Validation Accuracy: 57.38%
# Epoch 19/300, Train Loss: 0.9662, Train Accuracy: 57.01%, Validation Loss: 0.9861, Validation Accuracy: 54.68%
# Epoch 20/300, Train Loss: 0.9426, Train Accuracy: 57.56%, Validation Loss: 0.9278, Validation Accuracy: 57.96%
# Epoch 21/300, Train Loss: 0.9195, Train Accuracy: 59.44%, Validation Loss: 0.9184, Validation Accuracy: 57.86%
# Epoch 22/300, Train Loss: 0.9260, Train Accuracy: 60.02%, Validation Loss: 0.9052, Validation Accuracy: 58.73%
# Epoch 23/300, Train Loss: 0.9291, Train Accuracy: 59.03%, Validation Loss: 0.9261, Validation Accuracy: 57.96%
# Epoch 24/300, Train Loss: 0.8883, Train Accuracy: 60.77%, Validation Loss: 0.8969, Validation Accuracy: 60.95%
# Epoch 25/300, Train Loss: 0.8878, Train Accuracy: 60.67%, Validation Loss: 0.8824, Validation Accuracy: 60.27%
# Epoch 26/300, Train Loss: 0.8805, Train Accuracy: 61.47%, Validation Loss: 0.8937, Validation Accuracy: 59.31%
# Epoch 27/300, Train Loss: 0.8725, Train Accuracy: 60.94%, Validation Loss: 0.8979, Validation Accuracy: 59.79%
# Epoch 28/300, Train Loss: 0.8677, Train Accuracy: 62.65%, Validation Loss: 0.8960, Validation Accuracy: 59.40%
# Epoch 29/300, Train Loss: 0.8614, Train Accuracy: 62.02%, Validation Loss: 0.8450, Validation Accuracy: 62.97%
# Epoch 30/300, Train Loss: 0.8682, Train Accuracy: 61.83%, Validation Loss: 0.8807, Validation Accuracy: 62.10%
# Epoch 31/300, Train Loss: 0.8469, Train Accuracy: 62.67%, Validation Loss: 0.8699, Validation Accuracy: 62.58%
# Epoch 32/300, Train Loss: 0.8402, Train Accuracy: 63.35%, Validation Loss: 0.8531, Validation Accuracy: 60.56%
# Epoch 33/300, Train Loss: 0.8167, Train Accuracy: 64.53%, Validation Loss: 0.8574, Validation Accuracy: 61.72%
# Epoch 34/300, Train Loss: 0.8105, Train Accuracy: 64.58%, Validation Loss: 0.8850, Validation Accuracy: 60.56%
# Epoch 35/300, Train Loss: 0.8208, Train Accuracy: 64.48%, Validation Loss: 0.8498, Validation Accuracy: 61.52%
# Epoch 36/300, Train Loss: 0.7999, Train Accuracy: 64.55%, Validation Loss: 0.8560, Validation Accuracy: 61.72%
# Epoch 37/300, Train Loss: 0.7903, Train Accuracy: 65.42%, Validation Loss: 0.8246, Validation Accuracy: 63.74%
# Epoch 38/300, Train Loss: 0.8077, Train Accuracy: 65.25%, Validation Loss: 0.8449, Validation Accuracy: 63.07%
# Epoch 39/300, Train Loss: 0.7908, Train Accuracy: 65.01%, Validation Loss: 0.8451, Validation Accuracy: 63.55%
# Epoch 40/300, Train Loss: 0.7641, Train Accuracy: 67.78%, Validation Loss: 0.8064, Validation Accuracy: 64.32%
# Epoch 41/300, Train Loss: 0.7520, Train Accuracy: 67.35%, Validation Loss: 0.8449, Validation Accuracy: 63.26%
# Epoch 42/300, Train Loss: 0.7572, Train Accuracy: 67.47%, Validation Loss: 0.8244, Validation Accuracy: 63.84%
# Epoch 43/300, Train Loss: 0.7647, Train Accuracy: 66.65%, Validation Loss: 0.8504, Validation Accuracy: 62.49%
# Epoch 44/300, Train Loss: 0.7488, Train Accuracy: 67.71%, Validation Loss: 0.7976, Validation Accuracy: 64.42%
# Epoch 45/300, Train Loss: 0.7472, Train Accuracy: 67.95%, Validation Loss: 0.8290, Validation Accuracy: 64.22%
# Epoch 46/300, Train Loss: 0.7383, Train Accuracy: 68.72%, Validation Loss: 0.8258, Validation Accuracy: 62.78%
# Epoch 47/300, Train Loss: 0.7300, Train Accuracy: 68.70%, Validation Loss: 0.8070, Validation Accuracy: 65.96%
# Epoch 48/300, Train Loss: 0.7089, Train Accuracy: 68.46%, Validation Loss: 0.8257, Validation Accuracy: 64.71%
# Epoch 49/300, Train Loss: 0.7318, Train Accuracy: 68.75%, Validation Loss: 0.8062, Validation Accuracy: 65.57%
# Epoch 50/300, Train Loss: 0.6978, Train Accuracy: 70.51%, Validation Loss: 0.8326, Validation Accuracy: 63.55%
# Epoch 51/300, Train Loss: 0.6881, Train Accuracy: 70.44%, Validation Loss: 0.8251, Validation Accuracy: 65.48%
# Epoch 52/300, Train Loss: 0.6819, Train Accuracy: 70.99%, Validation Loss: 0.8367, Validation Accuracy: 63.65%
# Epoch 53/300, Train Loss: 0.6895, Train Accuracy: 70.82%, Validation Loss: 0.8123, Validation Accuracy: 64.32%
# Epoch 54/300, Train Loss: 0.6991, Train Accuracy: 70.27%, Validation Loss: 0.7870, Validation Accuracy: 65.28%
# Epoch 55/300, Train Loss: 0.6928, Train Accuracy: 71.33%, Validation Loss: 0.8079, Validation Accuracy: 64.90%
# Epoch 56/300, Train Loss: 0.6759, Train Accuracy: 70.48%, Validation Loss: 0.7981, Validation Accuracy: 64.13%
# Epoch 57/300, Train Loss: 0.6651, Train Accuracy: 72.68%, Validation Loss: 0.8010, Validation Accuracy: 64.80%
# Epoch 58/300, Train Loss: 0.6749, Train Accuracy: 71.84%, Validation Loss: 0.7800, Validation Accuracy: 66.83%
# Epoch 59/300, Train Loss: 0.6728, Train Accuracy: 70.87%, Validation Loss: 0.7717, Validation Accuracy: 68.08%
# Epoch 60/300, Train Loss: 0.6464, Train Accuracy: 72.15%, Validation Loss: 0.8524, Validation Accuracy: 63.07%
# Epoch 61/300, Train Loss: 0.6468, Train Accuracy: 72.56%, Validation Loss: 0.8142, Validation Accuracy: 64.80%
# Epoch 62/300, Train Loss: 0.6535, Train Accuracy: 73.04%, Validation Loss: 0.7982, Validation Accuracy: 65.86%
# Epoch 63/300, Train Loss: 0.6565, Train Accuracy: 71.64%, Validation Loss: 0.7847, Validation Accuracy: 66.83%
# Epoch 64/300, Train Loss: 0.6433, Train Accuracy: 72.24%, Validation Loss: 0.7844, Validation Accuracy: 67.31%
# Epoch 65/300, Train Loss: 0.6327, Train Accuracy: 73.26%, Validation Loss: 0.7786, Validation Accuracy: 66.06%
# Epoch 66/300, Train Loss: 0.6409, Train Accuracy: 73.28%, Validation Loss: 0.7936, Validation Accuracy: 66.73%
# Epoch 67/300, Train Loss: 0.6292, Train Accuracy: 72.44%, Validation Loss: 0.8004, Validation Accuracy: 66.35%
# Epoch 68/300, Train Loss: 0.6161, Train Accuracy: 74.29%, Validation Loss: 0.7994, Validation Accuracy: 67.02%
# Epoch 69/300, Train Loss: 0.6167, Train Accuracy: 73.84%, Validation Loss: 0.7855, Validation Accuracy: 67.31%
# Epoch 70/300, Train Loss: 0.6185, Train Accuracy: 73.21%, Validation Loss: 0.7870, Validation Accuracy: 67.70%
# Epoch 71/300, Train Loss: 0.6082, Train Accuracy: 74.80%, Validation Loss: 0.7809, Validation Accuracy: 67.79%
# Epoch 72/300, Train Loss: 0.6061, Train Accuracy: 74.20%, Validation Loss: 0.7835, Validation Accuracy: 67.79%
# Epoch 73/300, Train Loss: 0.6059, Train Accuracy: 73.64%, Validation Loss: 0.8062, Validation Accuracy: 66.35%
# Epoch 74/300, Train Loss: 0.6083, Train Accuracy: 73.96%, Validation Loss: 0.7800, Validation Accuracy: 67.12%
# Epoch 75/300, Train Loss: 0.5874, Train Accuracy: 74.49%, Validation Loss: 0.7776, Validation Accuracy: 68.37%
# Epoch 76/300, Train Loss: 0.5879, Train Accuracy: 74.99%, Validation Loss: 0.8090, Validation Accuracy: 67.31%
# Epoch 77/300, Train Loss: 0.5798, Train Accuracy: 75.50%, Validation Loss: 0.8040, Validation Accuracy: 66.54%
# Epoch 78/300, Train Loss: 0.5772, Train Accuracy: 75.57%, Validation Loss: 0.7628, Validation Accuracy: 68.56%
# Epoch 79/300, Train Loss: 0.5803, Train Accuracy: 75.55%, Validation Loss: 0.7922, Validation Accuracy: 67.12%
# Epoch 80/300, Train Loss: 0.5606, Train Accuracy: 77.19%, Validation Loss: 0.7942, Validation Accuracy: 67.60%
# Epoch 81/300, Train Loss: 0.5497, Train Accuracy: 76.92%, Validation Loss: 0.8010, Validation Accuracy: 67.21%
# Epoch 82/300, Train Loss: 0.5659, Train Accuracy: 75.77%, Validation Loss: 0.8191, Validation Accuracy: 67.31%
# Epoch 83/300, Train Loss: 0.5634, Train Accuracy: 76.27%, Validation Loss: 0.7826, Validation Accuracy: 67.41%
# Epoch 84/300, Train Loss: 0.5728, Train Accuracy: 75.57%, Validation Loss: 0.7577, Validation Accuracy: 69.05%
# Epoch 85/300, Train Loss: 0.5734, Train Accuracy: 76.27%, Validation Loss: 0.7948, Validation Accuracy: 67.41%
# Epoch 86/300, Train Loss: 0.5397, Train Accuracy: 77.43%, Validation Loss: 0.7893, Validation Accuracy: 67.12%
# Epoch 87/300, Train Loss: 0.5527, Train Accuracy: 76.66%, Validation Loss: 0.7855, Validation Accuracy: 69.33%
# Epoch 88/300, Train Loss: 0.5604, Train Accuracy: 76.78%, Validation Loss: 0.8008, Validation Accuracy: 68.66%
# Epoch 89/300, Train Loss: 0.5496, Train Accuracy: 76.51%, Validation Loss: 0.8138, Validation Accuracy: 68.37%
# Epoch 90/300, Train Loss: 0.5368, Train Accuracy: 77.24%, Validation Loss: 0.8696, Validation Accuracy: 65.19%
# Epoch 91/300, Train Loss: 0.5446, Train Accuracy: 77.45%, Validation Loss: 0.8139, Validation Accuracy: 66.25%
# Epoch 92/300, Train Loss: 0.5398, Train Accuracy: 77.67%, Validation Loss: 0.8152, Validation Accuracy: 68.56%
# Epoch 93/300, Train Loss: 0.5358, Train Accuracy: 77.98%, Validation Loss: 0.8138, Validation Accuracy: 67.31%
# Epoch 94/300, Train Loss: 0.5338, Train Accuracy: 77.69%, Validation Loss: 0.7969, Validation Accuracy: 68.37%
# Epoch 95/300, Train Loss: 0.5316, Train Accuracy: 78.39%, Validation Loss: 0.7955, Validation Accuracy: 67.79%
# Epoch 96/300, Train Loss: 0.5260, Train Accuracy: 77.79%, Validation Loss: 0.8025, Validation Accuracy: 68.56%
# Epoch 97/300, Train Loss: 0.5148, Train Accuracy: 79.12%, Validation Loss: 0.7997, Validation Accuracy: 67.70%
# Epoch 98/300, Train Loss: 0.5180, Train Accuracy: 77.98%, Validation Loss: 0.7840, Validation Accuracy: 68.66%
# Epoch 99/300, Train Loss: 0.5112, Train Accuracy: 78.80%, Validation Loss: 0.7923, Validation Accuracy: 68.76%
# Epoch 100/300, Train Loss: 0.5075, Train Accuracy: 78.54%, Validation Loss: 0.8009, Validation Accuracy: 67.31%
# Epoch 101/300, Train Loss: 0.5174, Train Accuracy: 78.37%, Validation Loss: 0.7955, Validation Accuracy: 68.37%
# Epoch 102/300, Train Loss: 0.5057, Train Accuracy: 78.78%, Validation Loss: 0.8256, Validation Accuracy: 67.41%
# Epoch 103/300, Train Loss: 0.4924, Train Accuracy: 80.23%, Validation Loss: 0.8615, Validation Accuracy: 67.12%
# Epoch 104/300, Train Loss: 0.5008, Train Accuracy: 78.78%, Validation Loss: 0.8396, Validation Accuracy: 67.79%
# Epoch 105/300, Train Loss: 0.4958, Train Accuracy: 79.55%, Validation Loss: 0.8063, Validation Accuracy: 68.95%
# Epoch 106/300, Train Loss: 0.4999, Train Accuracy: 78.95%, Validation Loss: 0.7891, Validation Accuracy: 69.82%
# Epoch 107/300, Train Loss: 0.4841, Train Accuracy: 79.70%, Validation Loss: 0.8091, Validation Accuracy: 68.27%
# Epoch 108/300, Train Loss: 0.4872, Train Accuracy: 79.94%, Validation Loss: 0.8052, Validation Accuracy: 68.47%
# Epoch 109/300, Train Loss: 0.4759, Train Accuracy: 80.52%, Validation Loss: 0.8385, Validation Accuracy: 70.30%
# Epoch 110/300, Train Loss: 0.4676, Train Accuracy: 81.19%, Validation Loss: 0.8497, Validation Accuracy: 67.50%
# Epoch 111/300, Train Loss: 0.4755, Train Accuracy: 80.20%, Validation Loss: 0.8031, Validation Accuracy: 69.05%
# Epoch 112/300, Train Loss: 0.4747, Train Accuracy: 80.64%, Validation Loss: 0.8160, Validation Accuracy: 69.24%
# Epoch 113/300, Train Loss: 0.4765, Train Accuracy: 80.23%, Validation Loss: 0.8341, Validation Accuracy: 68.37%
# Epoch 114/300, Train Loss: 0.4922, Train Accuracy: 79.53%, Validation Loss: 0.8117, Validation Accuracy: 69.43%
# Epoch 115/300, Train Loss: 0.4685, Train Accuracy: 80.03%, Validation Loss: 0.7847, Validation Accuracy: 70.59%
# Epoch 116/300, Train Loss: 0.4513, Train Accuracy: 80.88%, Validation Loss: 0.7995, Validation Accuracy: 68.85%
# Epoch 117/300, Train Loss: 0.4673, Train Accuracy: 80.52%, Validation Loss: 0.7998, Validation Accuracy: 69.33%
# Epoch 118/300, Train Loss: 0.4730, Train Accuracy: 80.08%, Validation Loss: 0.7826, Validation Accuracy: 70.68%
# Epoch 119/300, Train Loss: 0.4720, Train Accuracy: 80.71%, Validation Loss: 0.8147, Validation Accuracy: 68.76%
# Epoch 120/300, Train Loss: 0.4601, Train Accuracy: 80.76%, Validation Loss: 0.7810, Validation Accuracy: 70.88%
# Epoch 121/300, Train Loss: 0.4515, Train Accuracy: 81.41%, Validation Loss: 0.7962, Validation Accuracy: 69.14%
# Epoch 122/300, Train Loss: 0.4505, Train Accuracy: 82.04%, Validation Loss: 0.8318, Validation Accuracy: 69.43%
# Epoch 123/300, Train Loss: 0.4661, Train Accuracy: 80.20%, Validation Loss: 0.8138, Validation Accuracy: 69.05%
# Epoch 124/300, Train Loss: 0.4594, Train Accuracy: 81.94%, Validation Loss: 0.8446, Validation Accuracy: 67.12%
# Epoch 125/300, Train Loss: 0.4463, Train Accuracy: 81.79%, Validation Loss: 0.8047, Validation Accuracy: 69.62%
# Epoch 126/300, Train Loss: 0.4409, Train Accuracy: 82.25%, Validation Loss: 0.8203, Validation Accuracy: 68.66%
# Epoch 127/300, Train Loss: 0.4497, Train Accuracy: 81.41%, Validation Loss: 0.7913, Validation Accuracy: 70.40%
# Epoch 128/300, Train Loss: 0.4392, Train Accuracy: 82.04%, Validation Loss: 0.8394, Validation Accuracy: 68.18%
# Epoch 129/300, Train Loss: 0.4455, Train Accuracy: 81.70%, Validation Loss: 0.7946, Validation Accuracy: 69.33%
# Epoch 130/300, Train Loss: 0.4413, Train Accuracy: 82.06%, Validation Loss: 0.8336, Validation Accuracy: 69.14%
# Epoch 131/300, Train Loss: 0.4421, Train Accuracy: 82.13%, Validation Loss: 0.8234, Validation Accuracy: 69.05%
# Epoch 132/300, Train Loss: 0.4181, Train Accuracy: 82.88%, Validation Loss: 0.8196, Validation Accuracy: 70.59%
# Epoch 133/300, Train Loss: 0.4282, Train Accuracy: 82.30%, Validation Loss: 0.8427, Validation Accuracy: 68.56%
# Epoch 134/300, Train Loss: 0.4400, Train Accuracy: 81.43%, Validation Loss: 0.8345, Validation Accuracy: 68.76%
# Epoch 135/300, Train Loss: 0.4254, Train Accuracy: 82.69%, Validation Loss: 0.8216, Validation Accuracy: 70.78%
# Epoch 136/300, Train Loss: 0.4287, Train Accuracy: 81.91%, Validation Loss: 0.8384, Validation Accuracy: 68.27%
# Epoch 137/300, Train Loss: 0.4288, Train Accuracy: 82.83%, Validation Loss: 0.8148, Validation Accuracy: 68.66%
# Epoch 138/300, Train Loss: 0.4204, Train Accuracy: 82.45%, Validation Loss: 0.8378, Validation Accuracy: 68.95%
# Epoch 139/300, Train Loss: 0.4280, Train Accuracy: 82.47%, Validation Loss: 0.8087, Validation Accuracy: 69.62%
# Epoch 140/300, Train Loss: 0.4135, Train Accuracy: 83.00%, Validation Loss: 0.8307, Validation Accuracy: 69.53%
# Epoch 141/300, Train Loss: 0.4309, Train Accuracy: 81.72%, Validation Loss: 0.8379, Validation Accuracy: 69.14%
# Epoch 142/300, Train Loss: 0.4097, Train Accuracy: 83.77%, Validation Loss: 0.7855, Validation Accuracy: 71.84%
# Epoch 143/300, Train Loss: 0.4089, Train Accuracy: 83.82%, Validation Loss: 0.7903, Validation Accuracy: 69.53%
# Epoch 144/300, Train Loss: 0.4144, Train Accuracy: 83.17%, Validation Loss: 0.8085, Validation Accuracy: 70.01%
# Epoch 145/300, Train Loss: 0.4035, Train Accuracy: 83.67%, Validation Loss: 0.8274, Validation Accuracy: 68.37%
# Epoch 146/300, Train Loss: 0.4034, Train Accuracy: 84.42%, Validation Loss: 0.8349, Validation Accuracy: 67.98%
# Epoch 147/300, Train Loss: 0.4055, Train Accuracy: 83.60%, Validation Loss: 0.8443, Validation Accuracy: 68.66%
# Epoch 148/300, Train Loss: 0.3995, Train Accuracy: 83.82%, Validation Loss: 0.8151, Validation Accuracy: 69.72%
# Epoch 149/300, Train Loss: 0.3939, Train Accuracy: 84.21%, Validation Loss: 0.8683, Validation Accuracy: 68.56%
# Epoch 150/300, Train Loss: 0.4047, Train Accuracy: 83.84%, Validation Loss: 0.8603, Validation Accuracy: 69.82%
# Epoch 151/300, Train Loss: 0.4007, Train Accuracy: 84.35%, Validation Loss: 0.8194, Validation Accuracy: 69.72%
# Epoch 152/300, Train Loss: 0.3922, Train Accuracy: 84.42%, Validation Loss: 0.8526, Validation Accuracy: 68.56%
# Epoch 153/300, Train Loss: 0.3980, Train Accuracy: 84.04%, Validation Loss: 0.8628, Validation Accuracy: 69.14%
# Epoch 154/300, Train Loss: 0.4040, Train Accuracy: 83.67%, Validation Loss: 0.8520, Validation Accuracy: 69.91%
# Epoch 155/300, Train Loss: 0.3987, Train Accuracy: 83.80%, Validation Loss: 0.8373, Validation Accuracy: 69.62%
# Epoch 156/300, Train Loss: 0.3943, Train Accuracy: 84.13%, Validation Loss: 0.8602, Validation Accuracy: 69.43%
# Epoch 157/300, Train Loss: 0.3731, Train Accuracy: 84.62%, Validation Loss: 0.8850, Validation Accuracy: 68.76%
# Epoch 158/300, Train Loss: 0.4043, Train Accuracy: 83.63%, Validation Loss: 0.8322, Validation Accuracy: 69.05%
# Epoch 159/300, Train Loss: 0.3927, Train Accuracy: 83.92%, Validation Loss: 0.8343, Validation Accuracy: 69.43%
# Epoch 160/300, Train Loss: 0.3878, Train Accuracy: 83.94%, Validation Loss: 0.8761, Validation Accuracy: 67.12%
# Epoch 161/300, Train Loss: 0.3932, Train Accuracy: 84.42%, Validation Loss: 0.8536, Validation Accuracy: 70.88%
# Epoch 162/300, Train Loss: 0.3735, Train Accuracy: 84.59%, Validation Loss: 0.8531, Validation Accuracy: 69.91%
# Epoch 163/300, Train Loss: 0.3860, Train Accuracy: 83.77%, Validation Loss: 0.8848, Validation Accuracy: 67.70%
# Epoch 164/300, Train Loss: 0.3664, Train Accuracy: 85.31%, Validation Loss: 0.8493, Validation Accuracy: 71.46%
# Epoch 165/300, Train Loss: 0.3815, Train Accuracy: 84.74%, Validation Loss: 0.8191, Validation Accuracy: 71.65%
# Epoch 166/300, Train Loss: 0.3665, Train Accuracy: 84.71%, Validation Loss: 0.8254, Validation Accuracy: 71.84%
# Epoch 167/300, Train Loss: 0.3754, Train Accuracy: 84.40%, Validation Loss: 0.8590, Validation Accuracy: 71.07%
# Epoch 168/300, Train Loss: 0.3716, Train Accuracy: 85.22%, Validation Loss: 0.8744, Validation Accuracy: 68.76%
# Epoch 169/300, Train Loss: 0.3792, Train Accuracy: 85.03%, Validation Loss: 0.8797, Validation Accuracy: 70.01%
# Epoch 170/300, Train Loss: 0.3850, Train Accuracy: 84.49%, Validation Loss: 0.8567, Validation Accuracy: 68.27%
# Epoch 171/300, Train Loss: 0.3585, Train Accuracy: 85.75%, Validation Loss: 0.8442, Validation Accuracy: 70.20%
# Epoch 172/300, Train Loss: 0.3664, Train Accuracy: 85.07%, Validation Loss: 0.8746, Validation Accuracy: 68.56%
# Epoch 173/300, Train Loss: 0.3763, Train Accuracy: 85.22%, Validation Loss: 0.8707, Validation Accuracy: 69.72%
# Epoch 174/300, Train Loss: 0.3839, Train Accuracy: 84.23%, Validation Loss: 0.8588, Validation Accuracy: 71.94%
# Epoch 175/300, Train Loss: 0.3781, Train Accuracy: 84.78%, Validation Loss: 0.8814, Validation Accuracy: 70.20%
# Epoch 176/300, Train Loss: 0.3607, Train Accuracy: 85.77%, Validation Loss: 0.8332, Validation Accuracy: 70.88%
# Epoch 177/300, Train Loss: 0.3697, Train Accuracy: 85.22%, Validation Loss: 0.8165, Validation Accuracy: 71.84%
# Epoch 178/300, Train Loss: 0.3615, Train Accuracy: 85.58%, Validation Loss: 0.8576, Validation Accuracy: 71.65%
# Epoch 179/300, Train Loss: 0.3769, Train Accuracy: 84.81%, Validation Loss: 0.8310, Validation Accuracy: 71.07%
# Epoch 180/300, Train Loss: 0.3521, Train Accuracy: 85.97%, Validation Loss: 0.8427, Validation Accuracy: 70.49%
# Epoch 181/300, Train Loss: 0.3621, Train Accuracy: 85.31%, Validation Loss: 0.8324, Validation Accuracy: 71.46%
# Epoch 182/300, Train Loss: 0.3547, Train Accuracy: 86.06%, Validation Loss: 0.8430, Validation Accuracy: 70.01%
# Epoch 183/300, Train Loss: 0.3578, Train Accuracy: 85.65%, Validation Loss: 0.8311, Validation Accuracy: 70.97%
# Epoch 184/300, Train Loss: 0.3745, Train Accuracy: 84.74%, Validation Loss: 0.8247, Validation Accuracy: 70.68%
# Epoch 185/300, Train Loss: 0.3498, Train Accuracy: 86.45%, Validation Loss: 0.8461, Validation Accuracy: 70.97%
# Epoch 186/300, Train Loss: 0.3437, Train Accuracy: 85.92%, Validation Loss: 0.8361, Validation Accuracy: 71.07%
# Epoch 187/300, Train Loss: 0.3446, Train Accuracy: 85.63%, Validation Loss: 0.8521, Validation Accuracy: 70.40%
# Epoch 188/300, Train Loss: 0.3544, Train Accuracy: 85.87%, Validation Loss: 0.8412, Validation Accuracy: 71.26%
# Epoch 189/300, Train Loss: 0.3371, Train Accuracy: 86.93%, Validation Loss: 0.8556, Validation Accuracy: 70.49%
# Epoch 190/300, Train Loss: 0.3422, Train Accuracy: 87.03%, Validation Loss: 0.8363, Validation Accuracy: 71.65%
# Epoch 191/300, Train Loss: 0.3369, Train Accuracy: 86.74%, Validation Loss: 0.8497, Validation Accuracy: 70.88%
# Epoch 192/300, Train Loss: 0.3455, Train Accuracy: 86.18%, Validation Loss: 0.8376, Validation Accuracy: 71.65%
# Epoch 193/300, Train Loss: 0.3368, Train Accuracy: 86.71%, Validation Loss: 0.8723, Validation Accuracy: 69.62%
# Epoch 194/300, Train Loss: 0.3363, Train Accuracy: 86.06%, Validation Loss: 0.8454, Validation Accuracy: 71.65%
# Epoch 195/300, Train Loss: 0.3506, Train Accuracy: 86.54%, Validation Loss: 0.8735, Validation Accuracy: 70.78%
# Epoch 196/300, Train Loss: 0.3504, Train Accuracy: 86.76%, Validation Loss: 0.8580, Validation Accuracy: 70.49%
# Epoch 197/300, Train Loss: 0.3409, Train Accuracy: 86.76%, Validation Loss: 0.8551, Validation Accuracy: 70.30%
# Epoch 198/300, Train Loss: 0.3445, Train Accuracy: 86.42%, Validation Loss: 0.8431, Validation Accuracy: 72.13%
# Epoch 199/300, Train Loss: 0.3365, Train Accuracy: 86.40%, Validation Loss: 0.8598, Validation Accuracy: 70.59%
# Epoch 200/300, Train Loss: 0.3320, Train Accuracy: 86.81%, Validation Loss: 0.8425, Validation Accuracy: 71.84%
# Epoch 201/300, Train Loss: 0.3481, Train Accuracy: 86.09%, Validation Loss: 0.8376, Validation Accuracy: 70.97%
# Epoch 202/300, Train Loss: 0.3394, Train Accuracy: 85.97%, Validation Loss: 0.8592, Validation Accuracy: 70.30%
# Epoch 203/300, Train Loss: 0.3412, Train Accuracy: 86.40%, Validation Loss: 0.8660, Validation Accuracy: 70.68%
# Epoch 204/300, Train Loss: 0.3395, Train Accuracy: 86.86%, Validation Loss: 0.8413, Validation Accuracy: 71.07%
# Epoch 205/300, Train Loss: 0.3354, Train Accuracy: 86.67%, Validation Loss: 0.8477, Validation Accuracy: 70.78%
# Epoch 206/300, Train Loss: 0.3308, Train Accuracy: 86.74%, Validation Loss: 0.8619, Validation Accuracy: 70.68%
# Epoch 207/300, Train Loss: 0.3307, Train Accuracy: 87.27%, Validation Loss: 0.8702, Validation Accuracy: 70.40%
# Epoch 208/300, Train Loss: 0.3256, Train Accuracy: 86.81%, Validation Loss: 0.8580, Validation Accuracy: 70.97%
# Epoch 209/300, Train Loss: 0.3313, Train Accuracy: 87.27%, Validation Loss: 0.8427, Validation Accuracy: 71.55%
# Epoch 210/300, Train Loss: 0.3377, Train Accuracy: 86.59%, Validation Loss: 0.8434, Validation Accuracy: 70.49%
# Epoch 211/300, Train Loss: 0.3221, Train Accuracy: 87.44%, Validation Loss: 0.8750, Validation Accuracy: 69.72%
# Epoch 212/300, Train Loss: 0.3198, Train Accuracy: 87.97%, Validation Loss: 0.8552, Validation Accuracy: 70.30%
# Epoch 213/300, Train Loss: 0.3294, Train Accuracy: 86.04%, Validation Loss: 0.8693, Validation Accuracy: 70.01%
# Epoch 214/300, Train Loss: 0.3175, Train Accuracy: 87.75%, Validation Loss: 0.8377, Validation Accuracy: 70.97%
# Epoch 215/300, Train Loss: 0.3173, Train Accuracy: 87.32%, Validation Loss: 0.8568, Validation Accuracy: 70.78%
# Epoch 216/300, Train Loss: 0.3018, Train Accuracy: 87.85%, Validation Loss: 0.8806, Validation Accuracy: 70.20%
# Epoch 217/300, Train Loss: 0.3105, Train Accuracy: 87.53%, Validation Loss: 0.9105, Validation Accuracy: 69.24%
# Epoch 218/300, Train Loss: 0.3270, Train Accuracy: 86.71%, Validation Loss: 0.8663, Validation Accuracy: 71.26%
# Epoch 219/300, Train Loss: 0.3246, Train Accuracy: 87.34%, Validation Loss: 0.8457, Validation Accuracy: 71.55%
# Epoch 220/300, Train Loss: 0.3185, Train Accuracy: 86.64%, Validation Loss: 0.8834, Validation Accuracy: 70.40%
# Epoch 221/300, Train Loss: 0.2983, Train Accuracy: 87.99%, Validation Loss: 0.8760, Validation Accuracy: 71.36%
# Epoch 222/300, Train Loss: 0.3188, Train Accuracy: 87.29%, Validation Loss: 0.8711, Validation Accuracy: 70.59%
# Epoch 223/300, Train Loss: 0.2986, Train Accuracy: 87.97%, Validation Loss: 0.8940, Validation Accuracy: 70.30%
# Epoch 224/300, Train Loss: 0.3057, Train Accuracy: 87.75%, Validation Loss: 0.9029, Validation Accuracy: 70.59%
# Epoch 225/300, Train Loss: 0.3067, Train Accuracy: 88.52%, Validation Loss: 0.9195, Validation Accuracy: 70.49%
# Epoch 226/300, Train Loss: 0.2895, Train Accuracy: 88.57%, Validation Loss: 0.9029, Validation Accuracy: 70.78%
# Epoch 227/300, Train Loss: 0.3107, Train Accuracy: 87.77%, Validation Loss: 0.9314, Validation Accuracy: 68.47%
# Epoch 228/300, Train Loss: 0.2978, Train Accuracy: 88.50%, Validation Loss: 0.8720, Validation Accuracy: 72.13%
# Epoch 229/300, Train Loss: 0.2951, Train Accuracy: 88.86%, Validation Loss: 0.9287, Validation Accuracy: 68.27%
# Epoch 230/300, Train Loss: 0.3029, Train Accuracy: 88.18%, Validation Loss: 0.8732, Validation Accuracy: 71.36%
# Epoch 231/300, Train Loss: 0.3067, Train Accuracy: 88.11%, Validation Loss: 0.8862, Validation Accuracy: 71.36%
# Epoch 232/300, Train Loss: 0.2986, Train Accuracy: 87.68%, Validation Loss: 0.9138, Validation Accuracy: 71.36%
# Epoch 233/300, Train Loss: 0.2970, Train Accuracy: 88.09%, Validation Loss: 0.8765, Validation Accuracy: 70.78%
# Epoch 234/300, Train Loss: 0.2972, Train Accuracy: 88.57%, Validation Loss: 0.9135, Validation Accuracy: 70.01%
# Epoch 235/300, Train Loss: 0.3225, Train Accuracy: 87.00%, Validation Loss: 0.9258, Validation Accuracy: 69.53%
# Epoch 236/300, Train Loss: 0.2828, Train Accuracy: 88.71%, Validation Loss: 0.9152, Validation Accuracy: 69.53%
# Epoch 237/300, Train Loss: 0.3017, Train Accuracy: 88.30%, Validation Loss: 0.8738, Validation Accuracy: 71.65%
# Epoch 238/300, Train Loss: 0.2993, Train Accuracy: 88.47%, Validation Loss: 0.8919, Validation Accuracy: 71.36%
# Epoch 239/300, Train Loss: 0.3080, Train Accuracy: 88.11%, Validation Loss: 0.8977, Validation Accuracy: 69.53%
# Epoch 240/300, Train Loss: 0.2853, Train Accuracy: 88.35%, Validation Loss: 0.9441, Validation Accuracy: 69.05%
# Epoch 241/300, Train Loss: 0.2917, Train Accuracy: 88.55%, Validation Loss: 0.8994, Validation Accuracy: 71.26%
# Epoch 242/300, Train Loss: 0.3029, Train Accuracy: 88.26%, Validation Loss: 0.9048, Validation Accuracy: 71.84%
# Epoch 243/300, Train Loss: 0.2999, Train Accuracy: 87.82%, Validation Loss: 0.9403, Validation Accuracy: 68.66%
# Epoch 244/300, Train Loss: 0.2876, Train Accuracy: 88.71%, Validation Loss: 0.9045, Validation Accuracy: 70.40%
# Epoch 245/300, Train Loss: 0.3021, Train Accuracy: 88.74%, Validation Loss: 0.8661, Validation Accuracy: 71.07%
# Epoch 246/300, Train Loss: 0.2979, Train Accuracy: 88.30%, Validation Loss: 0.8652, Validation Accuracy: 71.36%
# Epoch 247/300, Train Loss: 0.2960, Train Accuracy: 88.45%, Validation Loss: 0.8479, Validation Accuracy: 71.84%
# Epoch 248/300, Train Loss: 0.2734, Train Accuracy: 89.34%, Validation Loss: 0.8649, Validation Accuracy: 72.52%
# Epoch 249/300, Train Loss: 0.2578, Train Accuracy: 90.23%, Validation Loss: 0.8925, Validation Accuracy: 70.88%
# Epoch 250/300, Train Loss: 0.2673, Train Accuracy: 89.27%, Validation Loss: 0.8829, Validation Accuracy: 71.17%
# Epoch 251/300, Train Loss: 0.2765, Train Accuracy: 89.32%, Validation Loss: 0.8947, Validation Accuracy: 71.07%
# Epoch 252/300, Train Loss: 0.2571, Train Accuracy: 90.40%, Validation Loss: 0.8703, Validation Accuracy: 72.13%
# Epoch 253/300, Train Loss: 0.2628, Train Accuracy: 89.80%, Validation Loss: 0.8680, Validation Accuracy: 72.42%
# Epoch 254/300, Train Loss: 0.2675, Train Accuracy: 89.66%, Validation Loss: 0.8458, Validation Accuracy: 71.84%
# Epoch 255/300, Train Loss: 0.2524, Train Accuracy: 90.57%, Validation Loss: 0.8508, Validation Accuracy: 72.52%
# Epoch 256/300, Train Loss: 0.2478, Train Accuracy: 90.79%, Validation Loss: 0.8867, Validation Accuracy: 72.13%
# Epoch 257/300, Train Loss: 0.2423, Train Accuracy: 90.38%, Validation Loss: 0.8828, Validation Accuracy: 72.03%
# Epoch 258/300, Train Loss: 0.2553, Train Accuracy: 90.16%, Validation Loss: 0.9166, Validation Accuracy: 71.07%
# Epoch 259/300, Train Loss: 0.2512, Train Accuracy: 89.99%, Validation Loss: 0.8875, Validation Accuracy: 71.46%
# Epoch 260/300, Train Loss: 0.2606, Train Accuracy: 90.07%, Validation Loss: 0.9098, Validation Accuracy: 70.78%
# Epoch 261/300, Train Loss: 0.2463, Train Accuracy: 90.33%, Validation Loss: 0.8911, Validation Accuracy: 71.55%
# Epoch 262/300, Train Loss: 0.2600, Train Accuracy: 89.68%, Validation Loss: 0.8896, Validation Accuracy: 71.75%
# Epoch 263/300, Train Loss: 0.2858, Train Accuracy: 88.74%, Validation Loss: 0.8634, Validation Accuracy: 72.32%
# Epoch 264/300, Train Loss: 0.2555, Train Accuracy: 90.86%, Validation Loss: 0.8939, Validation Accuracy: 70.97%
# Epoch 265/300, Train Loss: 0.2549, Train Accuracy: 90.07%, Validation Loss: 0.8902, Validation Accuracy: 72.52%
# Epoch 266/300, Train Loss: 0.2504, Train Accuracy: 90.62%, Validation Loss: 0.8864, Validation Accuracy: 72.71%
# Epoch 267/300, Train Loss: 0.2578, Train Accuracy: 90.19%, Validation Loss: 0.8715, Validation Accuracy: 72.61%
# Epoch 268/300, Train Loss: 0.2539, Train Accuracy: 90.02%, Validation Loss: 0.9021, Validation Accuracy: 71.55%
# Epoch 269/300, Train Loss: 0.2340, Train Accuracy: 90.98%, Validation Loss: 0.8898, Validation Accuracy: 72.03%
# Epoch 270/300, Train Loss: 0.2366, Train Accuracy: 90.69%, Validation Loss: 0.8805, Validation Accuracy: 72.13%
# Epoch 271/300, Train Loss: 0.2464, Train Accuracy: 90.86%, Validation Loss: 0.8849, Validation Accuracy: 72.03%
# Epoch 272/300, Train Loss: 0.2518, Train Accuracy: 90.14%, Validation Loss: 0.8863, Validation Accuracy: 71.26%
# Epoch 273/300, Train Loss: 0.2411, Train Accuracy: 90.74%, Validation Loss: 0.8789, Validation Accuracy: 72.61%
# Epoch 274/300, Train Loss: 0.2407, Train Accuracy: 90.21%, Validation Loss: 0.8861, Validation Accuracy: 72.13%
# Epoch 275/300, Train Loss: 0.2455, Train Accuracy: 90.69%, Validation Loss: 0.8960, Validation Accuracy: 72.03%
# Epoch 276/300, Train Loss: 0.2372, Train Accuracy: 90.79%, Validation Loss: 0.8609, Validation Accuracy: 72.61%
# Epoch 277/300, Train Loss: 0.2310, Train Accuracy: 91.42%, Validation Loss: 0.8608, Validation Accuracy: 72.61%
# Epoch 278/300, Train Loss: 0.2403, Train Accuracy: 90.79%, Validation Loss: 0.8641, Validation Accuracy: 73.19%
# Epoch 279/300, Train Loss: 0.2379, Train Accuracy: 90.43%, Validation Loss: 0.8676, Validation Accuracy: 72.23%
# Epoch 280/300, Train Loss: 0.2284, Train Accuracy: 91.08%, Validation Loss: 0.8635, Validation Accuracy: 73.19%
# Epoch 281/300, Train Loss: 0.2276, Train Accuracy: 90.72%, Validation Loss: 0.8822, Validation Accuracy: 73.10%
# Epoch 282/300, Train Loss: 0.2420, Train Accuracy: 90.48%, Validation Loss: 0.8856, Validation Accuracy: 73.10%
# Epoch 283/300, Train Loss: 0.2299, Train Accuracy: 90.96%, Validation Loss: 0.8804, Validation Accuracy: 72.32%
# Epoch 284/300, Train Loss: 0.2355, Train Accuracy: 90.76%, Validation Loss: 0.8663, Validation Accuracy: 72.81%
# Epoch 285/300, Train Loss: 0.2164, Train Accuracy: 91.75%, Validation Loss: 0.8776, Validation Accuracy: 72.71%
# Epoch 286/300, Train Loss: 0.2328, Train Accuracy: 91.32%, Validation Loss: 0.8677, Validation Accuracy: 74.06%
# Epoch 287/300, Train Loss: 0.2367, Train Accuracy: 91.05%, Validation Loss: 0.8683, Validation Accuracy: 73.58%
# Epoch 288/300, Train Loss: 0.2280, Train Accuracy: 90.81%, Validation Loss: 0.8777, Validation Accuracy: 73.00%
# Epoch 289/300, Train Loss: 0.2413, Train Accuracy: 91.01%, Validation Loss: 0.8749, Validation Accuracy: 73.10%
# Epoch 290/300, Train Loss: 0.2296, Train Accuracy: 91.27%, Validation Loss: 0.9088, Validation Accuracy: 71.94%
# Epoch 291/300, Train Loss: 0.2348, Train Accuracy: 91.15%, Validation Loss: 0.8893, Validation Accuracy: 72.23%
# Epoch 292/300, Train Loss: 0.2251, Train Accuracy: 91.46%, Validation Loss: 0.8995, Validation Accuracy: 72.23%
# Epoch 293/300, Train Loss: 0.2361, Train Accuracy: 90.60%, Validation Loss: 0.8838, Validation Accuracy: 72.61%
# Epoch 294/300, Train Loss: 0.2328, Train Accuracy: 90.67%, Validation Loss: 0.8926, Validation Accuracy: 72.90%
# Epoch 295/300, Train Loss: 0.2387, Train Accuracy: 90.93%, Validation Loss: 0.8825, Validation Accuracy: 71.46%
# Epoch 296/300, Train Loss: 0.2288, Train Accuracy: 90.96%, Validation Loss: 0.8788, Validation Accuracy: 72.61%
# Epoch 297/300, Train Loss: 0.2323, Train Accuracy: 91.08%, Validation Loss: 0.8747, Validation Accuracy: 73.00%
# Epoch 298/300, Train Loss: 0.2142, Train Accuracy: 91.87%, Validation Loss: 0.8728, Validation Accuracy: 73.00%
# Epoch 299/300, Train Loss: 0.2143, Train Accuracy: 91.99%, Validation Loss: 0.8701, Validation Accuracy: 72.71%
# Epoch 300/300, Train Loss: 0.2105, Train Accuracy: 91.95%, Validation Loss: 0.8805, Validation Accuracy: 72.71%
# Average Loss: 0.210477337575344
# Highest Train Accuracy: 0.9199421268386786

# %%
classes_list = ['Left', 'Right', 'Foot', 'Tongue']
eval_model = EvalModel(trained_cnn_lstm_model)

# %%
# Testing the model
accuracy, y_true, y_pred = eval_model.test_model(test_dataset)
# Out:
# /------------------------------/
# Test Accuracy: 72.71%
# /------------------------------/

# %%
# Classification report
eval_model.print_classification_report(y_true, y_pred, classes_list)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Left       0.71      0.73      0.72       259
#        Right       0.73      0.75      0.74       259
#         Foot       0.79      0.72      0.75       260
#       Tongue       0.68      0.70      0.69       259
#
#     accuracy                           0.73      1037
#    macro avg       0.73      0.73      0.73      1037
# weighted avg       0.73      0.73      0.73      1037

# %%
# Plot confusion matrix
eval_model.plot_confusion_matrix(y_true, y_pred, classes_list)

# %%
# Plot classification metrics like precision, recall, and f1-score
eval_model.plot_classification_metrics(y_true, y_pred, classes_list)
# Out:
# Cohen's Kappa: 0.6361
